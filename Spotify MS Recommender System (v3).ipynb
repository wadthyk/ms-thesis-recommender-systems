# %% [markdown]
# ## Chapter 5) Methodology
# Code for analysis and ML workflow to build a recommender system and find music item similarities based on a user's listening history and liked/saved songs.
#
#
# ##### Steps (Brief Overview):
#
# **Data Collection & Processing (EDA Part)**
# 1. load all data available and store in Pandas data frames
# 2. connect to Spotify API using developer console to extract song features
# 3. create separate DFs for songs/playlists collected by friends and MBTI playlists downloaded from Kaggle
#
# **Feature Extraction & Selection**
# 4. clean the data and select feature columns for the model
#
# **Content Based Filtering on Base Dataset**
# 5. applying the different ML Models on Baseline Dataset Using Content Based Filtering and Evaluating Initial Results
#
# **Incorperating MBTI Perosnality Types in the Recommendation Process**
# 6. adding additional feature column for MBTI personality type and create MBTI based DFs from Kaggle Datasets
# 7. applying use-item Matrix factorization and evaluate results
#
# **Compare Results**
# 8. compare the results of baseline model with MBTI implemented model

# %%
# importing libraries
import pandas as pd
import seaborn as sns

# importing spotify_songs dataset downloaded from Kaggle (https://www.kaggle.com/datasets/joebeachcapital/30000-spotify-songs/data?select=spotify_songs.csv)
df_spotify_songs = pd.read_csv('/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Kaggle Datasets/30000 Spotify Songs Dataset/spotify_songs.csv')

df_spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
# summarizing shape of the dataset's distribution
df_spotify_songs.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171000      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean           0.084747      0.190176      0.510561    120.881132
# std            0.224230      0.154317      0.233146     26.903624
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.960000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918000
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32833.000000
# mean   225799.811622
# std     59834.006182
# min      4000.000000
# 25%    187819.000000
# 50%    216000.000000
# 75%    253585.000000
# max    517810.000000

# %%
df_spotify_songs.head(10)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 5  7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Jack Wins Remix
# 6  2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 7  6b1RNvAcJjQH73eZO4BLAB           Post Malone (feat. RANI) - GATTÜSO Remix
# 8  7bF6tCO3gFb8INrEDcjNT5             Tough Love - Tiësto Remix / Radio Edit
# 9  1IXGILkPm0tOCNeq00kCPa                If I Can't Have You - Gryffin Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5        Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
# 6        Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 7         Sam Feldt                69  6703SRPsLkS4bPtMFFJes1
# 8            Avicii                68  7CvAfGvq4RlIwEbT9o8Iav
# 9      Shawn Mendes                67  4QxzbfSsVryEQwvPFEV5Iu
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
# 5  Beautiful People (feat. Khalid) [Jack Wins Remix]               2019-07-11
# 6                    Never Really Over (R3HAB Remix)               2019-07-26
# 7           Post Malone (feat. RANI) [GATTÜSO Remix]               2019-08-29
# 8                          Tough Love (Tiësto Remix)               2019-06-14
# 9                If I Can't Have You (Gryffin Remix)               2019-06-20
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
# 5     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -5.385
# 6     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   5    -4.788
# 7     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   4    -2.419
# 8     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -3.562
# 9     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   2    -4.552
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
# 5     1       0.1270        0.0799          0.000000    0.1430    0.585
# 6     0       0.0623        0.1870          0.000000    0.1760    0.152
# 7     0       0.0434        0.0335          0.000005    0.1110    0.367
# 8     1       0.0565        0.0249          0.000004    0.6370    0.366
# 9     1       0.0320        0.0567          0.000000    0.0919    0.590
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
# 5  124.982       163049
# 6  112.648       187675
# 7  127.936       207619
# 8  127.015       193187
# 9  124.957       253040
#
# [10 rows x 23 columns]

# %%
# identifying columns with null_values
df_spotify_songs.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
# coutning duplicate entries in dataframe
df_spotify_songs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Extracting Disliked Songs of a User using streaming history

# %%
# extracting the streaming history as JSON and save relevant columns as Pandas DF

import json
import pandas as pd

# Read the JSON file
with open('/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/00_Data_Wadthy_ESFJ/Spotify Account Data/StreamingHistory_music_0.json', 'r') as file:
    data = json.load(file)

# Extract the required fields
extracted_data = [
    {
        'artistName': item['artistName'],
        'trackName': item['trackName'],
        'msPlayed': item['msPlayed']
    }
    for item in data
]

# Create a pandas DataFrame
df = pd.DataFrame(extracted_data)

# Display the first few rows of the DataFrame
print(df.head())

# Save the DataFrame to a CSV file (optional)
# df.to_csv('streaming_history.csv', index=False)
# Out:
#      artistName     trackName  msPlayed
# 0  Taylor Swift     Enchanted     86091
# 1    Bruno Mars      Treasure    178560
# 2          ZICO      Any song    186465
# 3            IU          Coin    193080
# 4            IU  Hold my hand    195213

# %%
df.head(10)
# Out:
#      artistName       trackName  msPlayed
# 0  Taylor Swift       Enchanted     86091
# 1    Bruno Mars        Treasure    178560
# 2          ZICO        Any song    186465
# 3            IU            Coin    193080
# 4            IU    Hold my hand    195213
# 5      Eric Nam        Miss You    172634
# 6            IU           LILAC    214253
# 7            IU  Meaning of you    195631
# 8      G-DRAGON        WHO YOU?    201428
# 9           LAS      Love, This    168663

# %%
# creating a "like_dislike" column out of dataframe based on msPlayed (if <30000 then 0 / dislike else 1 / like)
df['like_dislike'] = (df['msPlayed'] > 30000).astype(int)

# %%
df.head(10)
# Out:
#      artistName       trackName  msPlayed  like_dislike
# 0  Taylor Swift       Enchanted     86091             1
# 1    Bruno Mars        Treasure    178560             1
# 2          ZICO        Any song    186465             1
# 3            IU            Coin    193080             1
# 4            IU    Hold my hand    195213             1
# 5      Eric Nam        Miss You    172634             1
# 6            IU           LILAC    214253             1
# 7            IU  Meaning of you    195631             1
# 8      G-DRAGON        WHO YOU?    201428             1
# 9           LAS      Love, This    168663             1

# %%
df_dislike = df[df['like_dislike'] == 0]

# %%
df_dislike.head(30)
# Out:
#             artistName                                      trackName  \
# 14        Taylor Swift              Lavender Haze - Felix Jaehn Remix
# 27             Whethan                                     Can't Hide
# 34          Anne-Marie                                           2002
# 45                 ASL                                When Loving You
# 46      Anderson .Paak                                Fire In The Sky
# 49                MYSM                                     Indie Feel
# 51          Bruno Mars                           Just the Way You Are
# 54        Jack Johnson                                 Washing Dishes
# 57            Jay Chou                                            青花瓷
# 58          The Script                     The Man Who Can't Be Moved
# 64            Jay Chou                                           告白氣球
# 68             Spotify                                     Willkommen
# 71         Frank Ocean                                   Self Control
# 73           MeloMance                                           Gift
# 80      Unknown Artist                                  Unknown Track
# 81      Unknown Artist                                  Unknown Track
# 82      Unknown Artist                                  Unknown Track
# 83      Unknown Artist                                  Unknown Track
# 97                Zedd                                   Make You Say
# 102         Jason Mraz                            I Feel Like Dancing
# 103           24kGoldn                         Mood (feat. iann dior)
# 106         Bruno Mars                                    Count on Me
# 111          MeloMance                                           Gift
# 118               AKMU                                           200%
# 123       Manila Killa                             Everyday, Everyday
# 126         Quinn XCII                                          Stacy
# 133        Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 138  The Piano Maestro                Antifragile - Piano Arrangement
# 140            Spotify                                     Willkommen
# 145              HONNE                      BACK ON TOP (feat. Griff)
#
#      msPlayed  like_dislike
# 14       4410             0
# 27      20145             0
# 34      21382             0
# 45       1440             0
# 46       1650             0
# 49       6832             0
# 51       4769             0
# 54       2430             0
# 57      17950             0
# 58       1760             0
# 64       1180             0
# 68       8351             0
# 71       6594             0
# 73      10110             0
# 80       1109             0
# 81        874             0
# 82       1322             0
# 83       1834             0
# 97      11080             0
# 102     10538             0
# 103      3882             0
# 106      1045             0
# 111      3500             0
# 118     22092             0
# 123      2590             0
# 126         0             0
# 133      4160             0
# 138       766             0
# 140      8351             0
# 145       390             0

# %%
# Create the 'like_dislike' column
df['like_dislike'] = (df['msPlayed'] > 30000).astype(int)

# Filter for disliked songs (like_dislike = 0)
df_dislike = df[df['like_dislike'] == 0]

# Filter for liked songs (like_dislike = 1)
df_like = df[df['like_dislike'] == 1]

# Remove entries where trackName is "Unknown Track"
df_dislike = df_dislike[df_dislike['trackName'] != "Unknown Track"]

# Drop duplicate values
df_dislike = df_dislike.drop_duplicates()

# getting a random sample of 200 entries out of the 
df_dislike_sampled = df_dislike.sample(n=200, random_state=42)

# %%
df_dislike_sampled.head(30)
# Out:
#                artistName                                   trackName  \
# 1576               The xx                                     Islands
# 4631           Quinn XCII                         Too Late (with AJR)
# 1220            Parachute                                 Without You
# 4726            Jung Kook                         Seven (feat. Latto)
# 5353          Nicky Youre                                     Sunroof
# 5962      The Band CAMINO                                      2 / 14
# 3775        Marek Hemmann                                      Gemini
# 328        French Montana                               Unforgettable
# 3403          Troye Sivan                                       YOUTH
# 3410         Taylor Swift                                   Enchanted
# 5831     Ludwig Göransson                                  Los Alamos
# 948             MeloMance                                        Gift
# 3719       Martin Solveig                    Intoxicated - Radio Edit
# 4450          Cheat Codes                                  Lean On Me
# 4650       John Splithoff          Show Me (feat. Madison Ryann Ward)
# 2211                 Lauv                                    Feelings
# 3082             okaywill                                        Cold
# 8744        Uncle Kracker                                   Follow Me
# 9856             Jai Nova                                      Higher
# 5426           John Mayer              Slow Dancing in a Burning Room
# 7473                 10CM        Someone You Used To Know (@kyulisme)
# 1016               Younha                                         빗소리
# 3655          The Wombats  Greek Tragedy - Oliver Nelson TikTok Remix
# 401            Conan Gray                                    Memories
# 2814           Ed Sheeran                                  I'm a Mess
# 5081    The Neighbourhood                             Sweater Weather
# 6541          Simple Plan         Jet Lag (feat. Natasha Bedingfield)
# 3042  5 Seconds of Summer                                  Youngblood
# 687         Cosmos People                                         自己來
# 2908          Joep Beving                                    For Mark
#
#       msPlayed  like_dislike
# 1576     29200             0
# 4631      4202             0
# 1220         0             0
# 4726       880             0
# 5353         0             0
# 5962       590             0
# 3775      1630             0
# 328      24685             0
# 3403      1250             0
# 3410       110             0
# 5831      1330             0
# 948        990             0
# 3719       507             0
# 4450     23741             0
# 4650      1200             0
# 2211     12790             0
# 3082      8056             0
# 8744      1860             0
# 9856      2066             0
# 5426      4363             0
# 7473      1151             0
# 1016      9380             0
# 3655      1390             0
# 401      10050             0
# 2814     10133             0
# 5081       570             0
# 6541      3600             0
# 3042      2995             0
# 687      27040             0
# 2908      5013             0

# %%
df_dislike_sampled.shape
# Out:
# (200, 4)

# %%
df_dislike_sampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1576 to 3316
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artistName    200 non-null    object
#  1   trackName     200 non-null    object
#  2   msPlayed      200 non-null    int64
#  3   like_dislike  200 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 7.8+ KB

# %%
df_dislike_sampled.isnull().sum()
# Out:
# artistName      0
# trackName       0
# msPlayed        0
# like_dislike    0
# dtype: int64

# %%
import pandas as pd
import requests
import base64

# Spotify API credentials
client_id = '582341de1c87493291783ae774754039'
client_secret = 'a21c97ce2062459a8f257d476ed5fe97'

# Function to get access token
def get_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()
    auth_data = {'grant_type': 'client_credentials'}
    auth_response = requests.post(auth_url, headers={'Authorization': f'Basic {auth_header}'}, data=auth_data)
    return auth_response.json()['access_token']

# Function to search for a track and get its URI
def get_track_uri(artist_name, track_name, access_token):
    search_url = 'https://api.spotify.com/v1/search'
    query = f"track:{track_name} artist:{artist_name}"
    search_params = {
        'q': query,
        'type': 'track',
        'limit': 1
    }
    search_response = requests.get(search_url, headers={'Authorization': f'Bearer {access_token}'}, params=search_params)

    if search_response.status_code == 200:
        results = search_response.json()
        if results['tracks']['items']:
            return results['tracks']['items'][0]['uri']
    return None

# Get access token
access_token = get_access_token(client_id, client_secret)

# Function to apply to each row of the DataFrame
def get_uri_for_row(row):
    return get_track_uri(row['artistName'], row['trackName'], access_token)

# Apply the function to each row and create a new 'track_uri' column
df_dislike_sampled['track_uri'] = df_dislike_sampled.apply(get_uri_for_row, axis=1)

# Display the first few rows of the updated DataFrame
print(df_dislike_sampled[['artistName', 'trackName', 'track_uri']].head())

# Optionally, save the updated DataFrame to a CSV file
# df_dislike.to_csv('disliked_songs_with_uris.csv', index=False)
# Out:
#        artistName            trackName                             track_uri
# 1576       The xx              Islands  spotify:track:6i5tYaGlOFDLILEB6HfJAa
# 4631   Quinn XCII  Too Late (with AJR)  spotify:track:3KE6KppohrzZMbo2ao7CZ2
# 1220    Parachute          Without You  spotify:track:6R6ux6KaKrhAg2EIB2krdU
# 4726    Jung Kook  Seven (feat. Latto)  spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 5353  Nicky Youre              Sunroof  spotify:track:5YqEzk3C5c3UZ1D5fJUlXA

# %%
df_dislike_sampled.head(20)
# Out:
#             artistName                           trackName  msPlayed  \
# 1576            The xx                             Islands     29200
# 4631        Quinn XCII                 Too Late (with AJR)      4202
# 1220         Parachute                         Without You         0
# 4726         Jung Kook                 Seven (feat. Latto)       880
# 5353       Nicky Youre                             Sunroof         0
# 5962   The Band CAMINO                              2 / 14       590
# 3775     Marek Hemmann                              Gemini      1630
# 328     French Montana                       Unforgettable     24685
# 3403       Troye Sivan                               YOUTH      1250
# 3410      Taylor Swift                           Enchanted       110
# 5831  Ludwig Göransson                          Los Alamos      1330
# 948          MeloMance                                Gift       990
# 3719    Martin Solveig            Intoxicated - Radio Edit       507
# 4450       Cheat Codes                          Lean On Me     23741
# 4650    John Splithoff  Show Me (feat. Madison Ryann Ward)      1200
# 2211              Lauv                            Feelings     12790
# 3082          okaywill                                Cold      8056
# 8744     Uncle Kracker                           Follow Me      1860
# 9856          Jai Nova                              Higher      2066
# 5426        John Mayer      Slow Dancing in a Burning Room      4363
#
#       like_dislike                             track_uri
# 1576             0  spotify:track:6i5tYaGlOFDLILEB6HfJAa
# 4631             0  spotify:track:3KE6KppohrzZMbo2ao7CZ2
# 1220             0  spotify:track:6R6ux6KaKrhAg2EIB2krdU
# 4726             0  spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 5353             0  spotify:track:5YqEzk3C5c3UZ1D5fJUlXA
# 5962             0  spotify:track:2QwpEi3eNToZCCMMRcOj0u
# 3775             0  spotify:track:5dwjQsS2ezI4NDnokvK7IM
# 328              0  spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 3403             0  spotify:track:1cOyWWUr3oXJIxY0AjJEx9
# 3410             0  spotify:track:3sW3oSbzsfecv9XoUdGs7h
# 5831             0  spotify:track:3JbVKGhp0WXqO3DK8Xeg0n
# 948              0  spotify:track:5eO04wLeM487N9qhPHPPoB
# 3719             0  spotify:track:0dbQ4h3cs8QE5fOPMYdDrX
# 4450             0  spotify:track:5acSb48zFAcXTdL5Wsk8xx
# 4650             0  spotify:track:3QkU3yJDpu7XITJz4uWSSg
# 2211             0  spotify:track:6r3duEAfFTH83DuoywkG20
# 3082             0  spotify:track:6UDxsNdXBPvlLOydyncRDa
# 8744             0  spotify:track:4KoecuyOpZaNFZ0UqVsllc
# 9856             0  spotify:track:4BShF07Q4mZh0L9Juoes0Z
# 5426             0  spotify:track:2jdAk8ATWIL3dwT47XpRfu

# %%
df_dislike_sampled.isnull().sum()
# Out:
# artistName      0
# trackName       0
# msPlayed        0
# like_dislike    0
# track_uri       7
# dtype: int64

# %%
df_dislike_sampled_final = df_dislike_sampled.drop(['msPlayed' ,'like_dislike'], axis=1)

# %%
df_dislike_sampled_final.head(20)
# Out:
# 1576    spotify:track:6i5tYaGlOFDLILEB6HfJAa
# 4631    spotify:track:3KE6KppohrzZMbo2ao7CZ2
# 1220    spotify:track:6R6ux6KaKrhAg2EIB2krdU
# 4726    spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 5353    spotify:track:5YqEzk3C5c3UZ1D5fJUlXA
# 5962    spotify:track:2QwpEi3eNToZCCMMRcOj0u
# 3775    spotify:track:5dwjQsS2ezI4NDnokvK7IM
# 328     spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 3403    spotify:track:1cOyWWUr3oXJIxY0AjJEx9
# 3410    spotify:track:3sW3oSbzsfecv9XoUdGs7h
# 5831    spotify:track:3JbVKGhp0WXqO3DK8Xeg0n
# 948     spotify:track:5eO04wLeM487N9qhPHPPoB
# 3719    spotify:track:0dbQ4h3cs8QE5fOPMYdDrX
# 4450    spotify:track:5acSb48zFAcXTdL5Wsk8xx
# 4650    spotify:track:3QkU3yJDpu7XITJz4uWSSg
# 2211    spotify:track:6r3duEAfFTH83DuoywkG20
# 3082    spotify:track:6UDxsNdXBPvlLOydyncRDa
# 8744    spotify:track:4KoecuyOpZaNFZ0UqVsllc
# 9856    spotify:track:4BShF07Q4mZh0L9Juoes0Z
# 5426    spotify:track:2jdAk8ATWIL3dwT47XpRfu
# Name: track_uri, dtype: object

# %%
df_dislike_sampled_final.shape
# Out:
# (200, 3)

# %%
df_dislike_sampled_final.head(20)
# Out:
#             artistName                           trackName  \
# 1576            The xx                             Islands
# 4631        Quinn XCII                 Too Late (with AJR)
# 1220         Parachute                         Without You
# 4726         Jung Kook                 Seven (feat. Latto)
# 5353       Nicky Youre                             Sunroof
# 5962   The Band CAMINO                              2 / 14
# 3775     Marek Hemmann                              Gemini
# 328     French Montana                       Unforgettable
# 3403       Troye Sivan                               YOUTH
# 3410      Taylor Swift                           Enchanted
# 5831  Ludwig Göransson                          Los Alamos
# 948          MeloMance                                Gift
# 3719    Martin Solveig            Intoxicated - Radio Edit
# 4450       Cheat Codes                          Lean On Me
# 4650    John Splithoff  Show Me (feat. Madison Ryann Ward)
# 2211              Lauv                            Feelings
# 3082          okaywill                                Cold
# 8744     Uncle Kracker                           Follow Me
# 9856          Jai Nova                              Higher
# 5426        John Mayer      Slow Dancing in a Burning Room
#
#                                  track_uri
# 1576  spotify:track:6i5tYaGlOFDLILEB6HfJAa
# 4631  spotify:track:3KE6KppohrzZMbo2ao7CZ2
# 1220  spotify:track:6R6ux6KaKrhAg2EIB2krdU
# 4726  spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 5353  spotify:track:5YqEzk3C5c3UZ1D5fJUlXA
# 5962  spotify:track:2QwpEi3eNToZCCMMRcOj0u
# 3775  spotify:track:5dwjQsS2ezI4NDnokvK7IM
# 328   spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 3403  spotify:track:1cOyWWUr3oXJIxY0AjJEx9
# 3410  spotify:track:3sW3oSbzsfecv9XoUdGs7h
# 5831  spotify:track:3JbVKGhp0WXqO3DK8Xeg0n
# 948   spotify:track:5eO04wLeM487N9qhPHPPoB
# 3719  spotify:track:0dbQ4h3cs8QE5fOPMYdDrX
# 4450  spotify:track:5acSb48zFAcXTdL5Wsk8xx
# 4650  spotify:track:3QkU3yJDpu7XITJz4uWSSg
# 2211  spotify:track:6r3duEAfFTH83DuoywkG20
# 3082  spotify:track:6UDxsNdXBPvlLOydyncRDa
# 8744  spotify:track:4KoecuyOpZaNFZ0UqVsllc
# 9856  spotify:track:4BShF07Q4mZh0L9Juoes0Z
# 5426  spotify:track:2jdAk8ATWIL3dwT47XpRfu

# %%
# dropping null values in the track_uri column
df_dislike_sampled_final = df_dislike_sampled_final.dropna()

# %%
df_dislike_sampled_final.shape
# Out:
# (193, 3)

# %%
# splitting track URI column to get track_id separately
df_dislike_sampled_final['track_id'] = df_dislike_sampled_final.iloc[:, 2].str.split(':').str.get(-1)

# %%
df_dislike_sampled_final.head(10)
# Out:
#            artistName            trackName  \
# 1576           The xx              Islands
# 4631       Quinn XCII  Too Late (with AJR)
# 1220        Parachute          Without You
# 4726        Jung Kook  Seven (feat. Latto)
# 5353      Nicky Youre              Sunroof
# 5962  The Band CAMINO               2 / 14
# 3775    Marek Hemmann               Gemini
# 328    French Montana        Unforgettable
# 3403      Troye Sivan                YOUTH
# 3410     Taylor Swift            Enchanted
#
#                                  track_uri                track_id
# 1576  spotify:track:6i5tYaGlOFDLILEB6HfJAa  6i5tYaGlOFDLILEB6HfJAa
# 4631  spotify:track:3KE6KppohrzZMbo2ao7CZ2  3KE6KppohrzZMbo2ao7CZ2
# 1220  spotify:track:6R6ux6KaKrhAg2EIB2krdU  6R6ux6KaKrhAg2EIB2krdU
# 4726  spotify:track:7x9aauaA9cu6tyfpHnqDLo  7x9aauaA9cu6tyfpHnqDLo
# 5353  spotify:track:5YqEzk3C5c3UZ1D5fJUlXA  5YqEzk3C5c3UZ1D5fJUlXA
# 5962  spotify:track:2QwpEi3eNToZCCMMRcOj0u  2QwpEi3eNToZCCMMRcOj0u
# 3775  spotify:track:5dwjQsS2ezI4NDnokvK7IM  5dwjQsS2ezI4NDnokvK7IM
# 328   spotify:track:3B54sVLJ402zGa6Xm4YGNe  3B54sVLJ402zGa6Xm4YGNe
# 3403  spotify:track:1cOyWWUr3oXJIxY0AjJEx9  1cOyWWUr3oXJIxY0AjJEx9
# 3410  spotify:track:3sW3oSbzsfecv9XoUdGs7h  3sW3oSbzsfecv9XoUdGs7h

# %%
df_dislike_sampled_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 1576 to 3316
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artistName  193 non-null    object
#  1   trackName   193 non-null    object
#  2   track_uri   193 non-null    object
#  3   track_id    193 non-null    object
# dtypes: object(4)
# memory usage: 7.5+ KB

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='582341de1c87493291783ae774754039', client_secret='a21c97ce2062459a8f257d476ed5fe97')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import time

def get_audio_features_batch(track_ids, batch_size=100):
    audio_features = []
    for i in range(0, len(track_ids), batch_size):
        batch = track_ids[i:i+batch_size]
        features = sp.audio_features(batch)
        audio_features.extend(features)
        time.sleep(1)  # Add a 1-second delay between batches to respect rate limits
    return audio_features

# %%
all_track_ids = df_dislike_sampled_final['track_id'].tolist()
all_audio_features = get_audio_features_batch(all_track_ids)

# %%
audio_features_df = pd.DataFrame(all_audio_features)
result_df = pd.merge(df_dislike_sampled_final, audio_features_df, left_on='track_id', right_on='id', how='left')

# %%
result_df.head(20)
# Out:
#           artistName                           trackName  \
# 0             The xx                             Islands
# 1         Quinn XCII                 Too Late (with AJR)
# 2          Parachute                         Without You
# 3          Jung Kook                 Seven (feat. Latto)
# 4        Nicky Youre                             Sunroof
# 5    The Band CAMINO                              2 / 14
# 6      Marek Hemmann                              Gemini
# 7     French Montana                       Unforgettable
# 8        Troye Sivan                               YOUTH
# 9       Taylor Swift                           Enchanted
# 10  Ludwig Göransson                          Los Alamos
# 11         MeloMance                                Gift
# 12    Martin Solveig            Intoxicated - Radio Edit
# 13       Cheat Codes                          Lean On Me
# 14    John Splithoff  Show Me (feat. Madison Ryann Ward)
# 15              Lauv                            Feelings
# 16              Lauv                            Feelings
# 17          okaywill                                Cold
# 18     Uncle Kracker                           Follow Me
# 19          Jai Nova                              Higher
#
#                                track_uri                track_id  \
# 0   spotify:track:6i5tYaGlOFDLILEB6HfJAa  6i5tYaGlOFDLILEB6HfJAa
# 1   spotify:track:3KE6KppohrzZMbo2ao7CZ2  3KE6KppohrzZMbo2ao7CZ2
# 2   spotify:track:6R6ux6KaKrhAg2EIB2krdU  6R6ux6KaKrhAg2EIB2krdU
# 3   spotify:track:7x9aauaA9cu6tyfpHnqDLo  7x9aauaA9cu6tyfpHnqDLo
# 4   spotify:track:5YqEzk3C5c3UZ1D5fJUlXA  5YqEzk3C5c3UZ1D5fJUlXA
# 5   spotify:track:2QwpEi3eNToZCCMMRcOj0u  2QwpEi3eNToZCCMMRcOj0u
# 6   spotify:track:5dwjQsS2ezI4NDnokvK7IM  5dwjQsS2ezI4NDnokvK7IM
# 7   spotify:track:3B54sVLJ402zGa6Xm4YGNe  3B54sVLJ402zGa6Xm4YGNe
# 8   spotify:track:1cOyWWUr3oXJIxY0AjJEx9  1cOyWWUr3oXJIxY0AjJEx9
# 9   spotify:track:3sW3oSbzsfecv9XoUdGs7h  3sW3oSbzsfecv9XoUdGs7h
# 10  spotify:track:3JbVKGhp0WXqO3DK8Xeg0n  3JbVKGhp0WXqO3DK8Xeg0n
# 11  spotify:track:5eO04wLeM487N9qhPHPPoB  5eO04wLeM487N9qhPHPPoB
# 12  spotify:track:0dbQ4h3cs8QE5fOPMYdDrX  0dbQ4h3cs8QE5fOPMYdDrX
# 13  spotify:track:5acSb48zFAcXTdL5Wsk8xx  5acSb48zFAcXTdL5Wsk8xx
# 14  spotify:track:3QkU3yJDpu7XITJz4uWSSg  3QkU3yJDpu7XITJz4uWSSg
# 15  spotify:track:6r3duEAfFTH83DuoywkG20  6r3duEAfFTH83DuoywkG20
# 16  spotify:track:6r3duEAfFTH83DuoywkG20  6r3duEAfFTH83DuoywkG20
# 17  spotify:track:6UDxsNdXBPvlLOydyncRDa  6UDxsNdXBPvlLOydyncRDa
# 18  spotify:track:4KoecuyOpZaNFZ0UqVsllc  4KoecuyOpZaNFZ0UqVsllc
# 19  spotify:track:4BShF07Q4mZh0L9Juoes0Z  4BShF07Q4mZh0L9Juoes0Z
#
#     danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0          0.871   0.472    4   -11.077     1       0.0756  ...    0.1450
# 1          0.731   0.630    4    -6.943     1       0.0637  ...    0.2620
# 2          0.564   0.864    4    -5.121     1       0.0341  ...    0.1820
# 3          0.788   0.841   11    -3.955     1       0.0432  ...    0.0772
# 4          0.768   0.714   10    -5.110     1       0.0401  ...    0.1500
# 5          0.607   0.709    9    -7.428     1       0.0538  ...    0.2940
# 6          0.793   0.637    8   -11.994     1       0.0930  ...    0.1430
# 7          0.726   0.769    6    -5.043     1       0.1230  ...    0.1040
# 8          0.628   0.737    7    -4.437     1       0.0410  ...    0.0777
# 9          0.520   0.553    8    -3.546     1       0.0269  ...    0.1650
# 10         0.511   0.399    2   -21.550     0       0.0430  ...    0.1360
# 11         0.673   0.444    4    -6.750     1       0.0279  ...    0.0867
# 12         0.792   0.688    0    -4.008     1       0.0386  ...    0.0972
# 13         0.686   0.738    9    -5.802     1       0.2870  ...    0.0505
# 14         0.789   0.599    6    -7.267     1       0.0390  ...    0.1760
# 15         0.700   0.394    9    -8.911     1       0.0328  ...    0.0801
# 16         0.700   0.394    9    -8.911     1       0.0328  ...    0.0801
# 17         0.877   0.311    9    -8.630     1       0.4640  ...    0.1010
# 18         0.817   0.585    5    -4.688     1       0.0301  ...    0.1470
# 19         0.785   0.734    1    -5.494     1       0.2080  ...    0.2180
#
#     valence    tempo            type                      id  \
# 0    0.7070  124.040  audio_features  6i5tYaGlOFDLILEB6HfJAa
# 1    0.6340   89.025  audio_features  3KE6KppohrzZMbo2ao7CZ2
# 2    0.5340   95.984  audio_features  6R6ux6KaKrhAg2EIB2krdU
# 3    0.9040  124.986  audio_features  7x9aauaA9cu6tyfpHnqDLo
# 4    0.8420  131.443  audio_features  5YqEzk3C5c3UZ1D5fJUlXA
# 5    0.5510   97.006  audio_features  2QwpEi3eNToZCCMMRcOj0u
# 6    0.3200  128.001  audio_features  5dwjQsS2ezI4NDnokvK7IM
# 7    0.7330   97.985  audio_features  3B54sVLJ402zGa6Xm4YGNe
# 8    0.5910   91.505  audio_features  1cOyWWUr3oXJIxY0AjJEx9
# 9    0.2270   81.949  audio_features  3sW3oSbzsfecv9XoUdGs7h
# 10   0.0341  100.033  audio_features  3JbVKGhp0WXqO3DK8Xeg0n
# 11   0.5230   80.008  audio_features  5eO04wLeM487N9qhPHPPoB
# 12   0.5020  124.987  audio_features  0dbQ4h3cs8QE5fOPMYdDrX
# 13   0.4500  101.829  audio_features  5acSb48zFAcXTdL5Wsk8xx
# 14   0.7110  124.017  audio_features  3QkU3yJDpu7XITJz4uWSSg
# 15   0.2410  103.041  audio_features  6r3duEAfFTH83DuoywkG20
# 16   0.2410  103.041  audio_features  6r3duEAfFTH83DuoywkG20
# 17   0.4630   94.027  audio_features  6UDxsNdXBPvlLOydyncRDa
# 18   0.9160  105.014  audio_features  4KoecuyOpZaNFZ0UqVsllc
# 19   0.5920  124.988  audio_features  4BShF07Q4mZh0L9Juoes0Z
#
#                                      uri  \
# 0   spotify:track:6i5tYaGlOFDLILEB6HfJAa
# 1   spotify:track:3KE6KppohrzZMbo2ao7CZ2
# 2   spotify:track:6R6ux6KaKrhAg2EIB2krdU
# 3   spotify:track:7x9aauaA9cu6tyfpHnqDLo
# 4   spotify:track:5YqEzk3C5c3UZ1D5fJUlXA
# 5   spotify:track:2QwpEi3eNToZCCMMRcOj0u
# 6   spotify:track:5dwjQsS2ezI4NDnokvK7IM
# 7   spotify:track:3B54sVLJ402zGa6Xm4YGNe
# 8   spotify:track:1cOyWWUr3oXJIxY0AjJEx9
# 9   spotify:track:3sW3oSbzsfecv9XoUdGs7h
# 10  spotify:track:3JbVKGhp0WXqO3DK8Xeg0n
# 11  spotify:track:5eO04wLeM487N9qhPHPPoB
# 12  spotify:track:0dbQ4h3cs8QE5fOPMYdDrX
# 13  spotify:track:5acSb48zFAcXTdL5Wsk8xx
# 14  spotify:track:3QkU3yJDpu7XITJz4uWSSg
# 15  spotify:track:6r3duEAfFTH83DuoywkG20
# 16  spotify:track:6r3duEAfFTH83DuoywkG20
# 17  spotify:track:6UDxsNdXBPvlLOydyncRDa
# 18  spotify:track:4KoecuyOpZaNFZ0UqVsllc
# 19  spotify:track:4BShF07Q4mZh0L9Juoes0Z
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6i5tYaGlOFDL...
# 1   https://api.spotify.com/v1/tracks/3KE6KppohrzZ...
# 2   https://api.spotify.com/v1/tracks/6R6ux6KaKrhA...
# 3   https://api.spotify.com/v1/tracks/7x9aauaA9cu6...
# 4   https://api.spotify.com/v1/tracks/5YqEzk3C5c3U...
# 5   https://api.spotify.com/v1/tracks/2QwpEi3eNToZ...
# 6   https://api.spotify.com/v1/tracks/5dwjQsS2ezI4...
# 7   https://api.spotify.com/v1/tracks/3B54sVLJ402z...
# 8   https://api.spotify.com/v1/tracks/1cOyWWUr3oXJ...
# 9   https://api.spotify.com/v1/tracks/3sW3oSbzsfec...
# 10  https://api.spotify.com/v1/tracks/3JbVKGhp0WXq...
# 11  https://api.spotify.com/v1/tracks/5eO04wLeM487...
# 12  https://api.spotify.com/v1/tracks/0dbQ4h3cs8QE...
# 13  https://api.spotify.com/v1/tracks/5acSb48zFAcX...
# 14  https://api.spotify.com/v1/tracks/3QkU3yJDpu7X...
# 15  https://api.spotify.com/v1/tracks/6r3duEAfFTH8...
# 16  https://api.spotify.com/v1/tracks/6r3duEAfFTH8...
# 17  https://api.spotify.com/v1/tracks/6UDxsNdXBPvl...
# 18  https://api.spotify.com/v1/tracks/4KoecuyOpZaN...
# 19  https://api.spotify.com/v1/tracks/4BShF07Q4mZh...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/6i5t...      160720
# 1   https://api.spotify.com/v1/audio-analysis/3KE6...      175760
# 2   https://api.spotify.com/v1/audio-analysis/6R6u...      228933
# 3   https://api.spotify.com/v1/audio-analysis/7x9a...      184400
# 4   https://api.spotify.com/v1/audio-analysis/5YqE...      163026
# 5   https://api.spotify.com/v1/audio-analysis/2Qwp...      163690
# 6   https://api.spotify.com/v1/audio-analysis/5dwj...      547560
# 7   https://api.spotify.com/v1/audio-analysis/3B54...      233902
# 8   https://api.spotify.com/v1/audio-analysis/1cOy...      185194
# 9   https://api.spotify.com/v1/audio-analysis/3sW3...      353253
# 10  https://api.spotify.com/v1/audio-analysis/3JbV...      158573
# 11  https://api.spotify.com/v1/audio-analysis/5eO0...      260607
# 12  https://api.spotify.com/v1/audio-analysis/0dbQ...      159560
# 13  https://api.spotify.com/v1/audio-analysis/5acS...      149857
# 14  https://api.spotify.com/v1/audio-analysis/3QkU...      205720
# 15  https://api.spotify.com/v1/audio-analysis/6r3d...      189907
# 16  https://api.spotify.com/v1/audio-analysis/6r3d...      189907
# 17  https://api.spotify.com/v1/audio-analysis/6UDx...      224681
# 18  https://api.spotify.com/v1/audio-analysis/4Koe...      218440
# 19  https://api.spotify.com/v1/audio-analysis/4BSh...      148560
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
#
# [20 rows x 22 columns]

# %%
result_df['MBTI'] = 'ESFJ' # --> change as per MBTI type

# %%
# Save the extended DataFrame
result_df.to_csv('extended_songs_wadthy_dislike.csv', index=False)  # --> change as per Name
