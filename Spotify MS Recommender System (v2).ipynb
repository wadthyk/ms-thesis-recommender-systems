# %% [markdown]
# # Extracting Audio Features from PLaylist IDs

# %% [markdown]
# # Test

# %%
import json
import pandas as pd
import os

# List of JSON file paths --> local file path
file_paths = [
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/01_YourLibrary_withy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/02_YourLibrary_yoojin.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/03_YourLibrary_moni.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/04_YourLibrary_nga.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/05_YourLibrary_makra.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/06_YourLibrary_soeren.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/07_YourLibrary_simon.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/09_YourLibrary_yeonju.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/10_YourLibrary_han.json'
]

# Dictionary to store DataFrames
dataframes = {}

# Loop through each file, load the data, and create a DataFrame
for file_path in file_paths:
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Extract song information
    songs = data['tracks']

    # Create a list to hold song data
    song_list = []

    # Iterate over each song and extract relevant details
    for song in songs:
        song_info = {
            'Title': song.get('track', 'N/A'),
            'Artist': song.get('artist', 'N/A'),
            'Album': song.get('album', 'N/A'),
            'URI': song.get('uri', 'N/A')
        }
        song_list.append(song_info)

    # Create a DataFrame from the song list
    df = pd.DataFrame(song_list)

    # Use the file name (without extension) as the key for the DataFrame in the dictionary
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    dataframes[file_name] = df

# Accessing and analyzing individual DataFrames
for name, df in dataframes.items():
    print(f"DataFrame for {name}:")
    print(df.head())  # Display the first few rows of the DataFrame

    # Example analysis: Print the number of songs in each DataFrame
    print(f"Number of songs in {name}: {len(df)}")

    # Optionally, save each DataFrame to a separate CSV file
    df.to_csv(f'{name}_songs.csv', index=False)

# Example of specific DataFrame access for further analysis
# Access a specific DataFrame by its key, e.g., "05_YourLibrary_makra" --> getting DFs of all collected Users
df_wadthy = dataframes.get("00_YourLibrary_wadthy") # 3157 entries
df_withy = dataframes.get("01_YourLibrary_withy") # 601
df_yoojin = dataframes.get("02_YourLibrary_yoojin") # 46
df_moni = dataframes.get("03_YourLibrary_moni") # 13
df_nga = dataframes.get("04_YourLibrary_nga") # 1152
df_makra = dataframes.get("05_YourLibrary_makra") # 12
df_soeren = dataframes.get("06_YourLibrary_soeren") # 1086
df_simon = dataframes.get("07_YourLibrary_simon") # 681
# van's daten
df_yeonju = dataframes.get("09_YourLibrary_yeonju") # 260
df_han = dataframes.get("10_YourLibrary_han") # 106
# trang's daten
# Out:
# DataFrame for 00_YourLibrary_wadthy:
#                      Title       Artist              Album  \
# 0  Smells Like Teen Spirit      Nirvana            Nirvana
# 1               Sure Thing       Miguel  All I Want Is You
# 2              Fancy Shoes  The Walters     Songs for Dads
# 3                Tokyo Inn       HYUKOH                 23
# 4             Konoha Peace         Kato       Naruto Vibes
#
#                                     URI
# 0  spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1  spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2  spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3  spotify:track:4myeBw35GUMw5FyDGZcOON
# 4  spotify:track:0wIfYaveiZku0eL44UXtHk
# Number of songs in 00_YourLibrary_wadthy: 3157
# DataFrame for 01_YourLibrary_withy:
#                                        Title           Artist          Album  \
# 0  Ordinaryish People (feat. Blue Man Group)              AJR   OK ORCHESTRA
# 1                                   Good Day       Jake Scott       Lavender
# 2                                 Oh My Love        The Score          ATLAS
# 3                              Conversations           Marney  Conversations
# 4                                      Bones  Imagine Dragons          Bones
#
#                                     URI
# 0  spotify:track:3sBdf3nxnEC9e2GcdP9d3j
# 1  spotify:track:5zsTxXxpVzWC9MqeNJ3Pes
# 2  spotify:track:4Q99wmrzQFtK3oweyLkWij
# 3  spotify:track:6XfjfDpIUWI0sE0WBBnQfD
# 4  spotify:track:0HqZX76SFLDz2aW8aiqi7G
# Number of songs in 01_YourLibrary_withy: 601
# DataFrame for 02_YourLibrary_yoojin:
#                                    Title       Artist  \
# 0                  TOO BAD (prod. CarTa)  Anandelight
# 1  Young, Wild & Free (feat. Bruno Mars)   Snoop Dogg
# 2               Dancing in the Moonlight    Toploader
# 3                                  NDGGA       meenoi
# 4                        Etude of Memory   Exhibition
#
#                                    Album                                   URI
# 0                                TOO BAD  spotify:track:06vHdq1RN59tke4Ixq6usN
# 1  Young, Wild & Free (feat. Bruno Mars)  spotify:track:5HQVUIKwCEXpe7JIHyY734
# 2                        Onka's Big Moka  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 3                                  NDGGA  spotify:track:4k4PQkx007qoo6XPbijp9z
# 4                             Exhibition  spotify:track:3YpiZu52TdVbNKExZpZAWW
# Number of songs in 02_YourLibrary_yoojin: 46
# DataFrame for 03_YourLibrary_moni:
#              Title         Artist            Album  \
# 0         Too Much    DOLLA $LICE         Too Much
# 1  Let Me Love You    DOLLA $LICE  Let Me Love You
# 2            Vault  Ty Luminosity            Vault
# 3              YUH  Ty Luminosity              YUH
# 4          Candles   Zak Downtown          Candles
#
#                                     URI
# 0  spotify:track:3rAsEf7NeRAL4Dn3Z4yNtb
# 1  spotify:track:7DoCpSWH2qK5eblDQA0YKx
# 2  spotify:track:1bESEVLHPx4g8UzWcgdzJf
# 3  spotify:track:6RVklIYiEN5IGTVBDa7OzZ
# 4  spotify:track:6a1mSSxp5E3g2HRKquPmAg
# Number of songs in 03_YourLibrary_moni: 13
# DataFrame for 04_YourLibrary_nga:
#                                          Title         Artist  \
# 0  Wat's Wrong (feat. Zacari & Kendrick Lamar)  Isaiah Rashad
# 1                                         HITS      Kid Milli
# 2                                       Winter         Khalid
# 3                                    I Want In       88rising
# 4                                   Stars 별의 별   CRUCiAL STAR
#
#                 Album                                   URI
# 0    The Sun's Tirade  spotify:track:2RPbEp0DyBVlkRvvYKopO7
# 1             L I F E  spotify:track:07Emw7xeVExRPryephzm5w
# 2       American Teen  spotify:track:4V3VshJLUTCIWa77YiAkvM
# 3  Head In The Clouds  spotify:track:5ZaaHM8HRizjncGBAIfK0C
# 4         Maze Garden  spotify:track:7bnFxqjO7FB3NyzDAafdKi
# Number of songs in 04_YourLibrary_nga: 1152
# DataFrame for 05_YourLibrary_makra:
#                   Title        Artist  Album  \
# 0           Maria Maria  Kendji Girac  Amigo
# 1            Si je pars  Kendji Girac  Amigo
# 2        Tu vas manquer  Kendji Girac  Amigo
# 3  Que Dieu me pardonne  Kendji Girac  Amigo
# 4            Yo Cantare  Kendji Girac  Amigo
#
#                                     URI
# 0  spotify:track:2t6aqeXvLJ6ewrxFLcviOS
# 1  spotify:track:6yeRgCv8nriUNCK7PDaBBi
# 2  spotify:track:5Qjoee7cfoWXWZMw9A0jEJ
# 3  spotify:track:0hHNjDAThUngWzegMB4YYU
# 4  spotify:track:20gQarst0djq8xdZr6ukHK
# Number of songs in 05_YourLibrary_makra: 12
# DataFrame for 06_YourLibrary_soeren:
#                                Title                           Artist  \
# 0                         Last Dance                         Dua Lipa
# 1  Valerie - BBC Radio 1 Live Lounge                    Amy Winehouse
# 2                         Good Thing                        Sam Smith
# 3                     Wild Man Blues  Louis Armstrong & His Hot Seven
# 4                      Terrible Love                            Birdy
#
#                                                Album  \
# 0                                           Dua Lipa
# 1                                                AMY
# 2                                 In The Lonely Hour
# 3  Milestones of a Jazz Legend: Louis Armstrong, ...
# 4                                              Birdy
#
#                                     URI
# 0  spotify:track:5GXGDNTZvr4YomLHZsUb3N
# 1  spotify:track:1879aiUSpb1qNoiwtQA2XH
# 2  spotify:track:5rn8Cat391ffkBLo5weXl0
# 3  spotify:track:6VNU8BkeuCRzxwTs34dkgy
# 4  spotify:track:52EWTw5ALe9OnjgAxX3Luo
# Number of songs in 06_YourLibrary_soeren: 1086
# DataFrame for 07_YourLibrary_simon:
#                            Title                   Artist  \
# 0  Growing Up (feat. Ed Sheeran)  Macklemore & Ryan Lewis
# 1      Back for Good - Radio Mix                Take That
# 2                   The Greatest                      Sia
# 3                       Vendetta                  Chakuza
# 4  See Her Out (Thats Just Life)   Francis and the Lights
#
#                                                Album  \
# 0                         This Unruly Mess I've Made
# 1                               Nobody Else (Deluxe)
# 2                    This Is Acting (Deluxe Version)
# 3  ersguterjunge Sampler Vol.2 - Vendetta - Rerel...
# 4                                Farewell, Starlite!
#
#                                     URI
# 0  spotify:track:44T13PWJ87jb3lFElhVIHx
# 1  spotify:track:24fQpRwKFkC3Fe8QtvvrNw
# 2  spotify:track:6bLopGnirdrilrpdVB6Um1
# 3  spotify:track:47jBE0e53JfnUMqoqWjT2d
# 4  spotify:track:5zheSFviZNgeZLvZCOxQnE
# Number of songs in 07_YourLibrary_simon: 681
# DataFrame for 09_YourLibrary_yeonju:
#                                    Title        Artist                 Album  \
# 0                             WE GO HIGH       Roy Kim            WE GO HIGH
# 1                   Say You Won't Let Go  James Arthur    Back from the Edge
# 2  Your Side Of The Bed (feat. Eric Nam)         Loote  Your Side Of The Bed
# 3                              Nostalgia         Woody             Nostalgia
# 4                Electric (feat. Khalid)   Alina Baraz      The Color Of You
#
#                                     URI
# 0  spotify:track:2xiMbOHBJhAysqRSTLMYnk
# 1  spotify:track:5uCax9HTNlzGybIStD3vDh
# 2  spotify:track:3dz63QjQVZy7RYPzx6l3JU
# 3  spotify:track:6USuf8mq2X9jgvvv6MZldZ
# 4  spotify:track:2mj7x99sNUsVHPBRK51zlG
# Number of songs in 09_YourLibrary_yeonju: 260
# DataFrame for 10_YourLibrary_han:
#               Title       Artist  \
# 0     Grand Central  Ola Strandh
# 1            Ambush     Tim Wynn
# 2             Bliss  Ola Strandh
# 3  Advent Coalition     Tim Wynn
# 4           Victory     Tim Wynn
#
#                                                Album  \
# 0  Tom Clancy's The Division (Original Game Sound...
# 1   XCOM 2 (Original Soundtrack from the Video Game)
# 2  Tom Clancy's The Division (Original Game Sound...
# 3   XCOM 2 (Original Soundtrack from the Video Game)
# 4   XCOM 2 (Original Soundtrack from the Video Game)
#
#                                     URI
# 0  spotify:track:0WNjYlfwunIeIdq3HMPkml
# 1  spotify:track:72FIKI93KFHUsDMDmzn3EN
# 2  spotify:track:0h2vlb6QhN9kAve9dWHImr
# 3  spotify:track:0HFkJfrrQLKeU5ciGPFtZk
# 4  spotify:track:5ud7CJJQP0TAMFFtqiVZuG
# Number of songs in 10_YourLibrary_han: 106

# %%
# getting random sample of 300 entries for each of the MBTI DFs to reduce the chance of hitting the Spotify API rate limit

df_wadthy_sampled = df_wadthy.sample(n=200, random_state=42) # random_state=42 to make the DF reproducible
df_withy_sampled = df_withy.sample(n=200, random_state=42)
# df_yoojin_sampled = df_yoojin.sample(n=min(300, len(df)), random_state=42) -- has already less than 300 entries
# df_moni_sampled = df_moni.sample(n=min(300, len(df)), random_state=42)
df_nga_sampled = df_nga.sample(n=200, random_state=42)
#df_makra_sampled = df_makra.sample(n=300, random_state=42)
df_soeren_sampled = df_soeren.sample(n=200, random_state=42)
df_simon_sampled = df_simon.sample(n=200, random_state=42)
df_yeonju_sampled = df_yeonju.sample(n=200, random_state=42)
df_han_sampled = df_han.sample(n=100, random_state=42)

# %%
df_yeonju_sampled.head(20)
# Out:
#                                       Title            Artist  \
# 30                               superstars  Christian French
# 181                             Dangerously      Charlie Puth
# 223                            Love Is Gone           SLANDER
# 185  Running Up That Hill (A Deal With God)         Kate Bush
# 211                        I'm The Greatest           TAEYEON
# 258               Strawberries & Cigarettes       Troye Sivan
# 173                             To the Dawn              MRCH
# 142                        learned from you              Munn
# 9                           Ross And Rachel       Jake Miller
# 177                            Just Friends      Why Don't We
# 24                         I Feel It Coming        The Weeknd
# 213    Teardrops on My Guitar - Pop Version      Taylor Swift
# 77                           Because Of You             Ne-Yo
# 204               It Ain't Wrong Loving You             HONNE
# 190                            Cruel Summer           MC Dodo
# 206                               24/7, 365      elijah woods
# 242                                   Heavy         Peach PRC
# 6                                  사랑하기 때문에        Yoo Jae-Ha
# 220                               Love Back      Why Don't We
# 104           Summer Is for Falling in Love        Sarah Kang
#
#                              Album                                   URI
# 30                      superstars  spotify:track:0TqaX16qLpX7YqFcAl9lDy
# 181                Nine Track Mind  spotify:track:3qonjOrhFCfTnaaMruHzxW
# 223                   Love Is Gone  spotify:track:39glqzRVRAy4vq3PqeTGb8
# 185                 Hounds Of Love  spotify:track:1PtQJZVZIdWIYdARpZRDFO
# 211                           Stay  spotify:track:4vAQgQxs2gY3TlXBALUsKM
# 258      Strawberries & Cigarettes  spotify:track:3afkJSKX0EAMsJXTZnDXXJ
# 173                    To the Dawn  spotify:track:1fDQ8cZ2CWJY06zfdgv3m3
# 142                    only human.  spotify:track:1LssaQkPdWYdTfna8B0198
# 9                 Silver Lining II  spotify:track:4vCiNW18AyeaUAZosVnX61
# 177                   Just Friends  spotify:track:0tjYK2gtxo8fT2kdD4XGeF
# 24                         Starboy  spotify:track:3dhjNA0jGA8vHBQ1VdD6vV
# 213                   Taylor Swift  spotify:track:1hxLyjC9D9Jpw6EAPKqWv4
# 77                  Because Of You  spotify:track:6CFPFnS9EcLs2I0nWqtWci
# 204           Warm on a Cold Night  spotify:track:46dEPk9Luf1gokLNZWEZwN
# 190                   Cruel Summer  spotify:track:6Q8oTV3qKJEZR1FDuj1hyk
# 206                      24/7, 365  spotify:track:05QUYSOApWLr8oBbpONl7p
# 242                          Heavy  spotify:track:4UMWqTR58mUBRkFQkc0tle
# 6                         사랑하기 때문에  spotify:track:0I9vXVUpijjek2ULH4UUJw
# 220                      Love Back  spotify:track:7weX6syqklVQocpVVmDNwI
# 104  Summer Is for Falling in Love  spotify:track:6yfGer1TKpxOjhSd5eL0DL

# %%
df_yoojin['track_id'] = df_yoojin.iloc[:, 3].str.split(':').str.get(-1)

# %%
df_yoojin.head(20)
# Out:
#                                                 Title                 Artist  \
# 0                               TOO BAD (prod. CarTa)            Anandelight
# 1               Young, Wild & Free (feat. Bruno Mars)             Snoop Dogg
# 2                            Dancing in the Moonlight              Toploader
# 3                                               NDGGA                 meenoi
# 4                                     Etude of Memory             Exhibition
# 5                                             Weekend                TAEYEON
# 6                                      Ah Koritsi Mou     Giannis Ploutarhos
# 7                                           Bumblebee                   ABBA
# 8                                      Den Thelo Allo     Giannis Ploutarhos
# 9                                  The Rubberband Man           The Spinners
# 10  Reset (Feat. Gaeko, Kid Milli) (Prod. CODE KUNST)                  SINCE
# 11                                         Take A Bow                Rihanna
# 12                                           Sir Duke  Quartet San Francisco
# 13                                          친구로 지내자면서          Hwang In Wook
# 14                                           DOWNPOUR                  I.O.I
# 15                Don't Stop Me Now - Remastered 2011                  Queen
# 16                                   LOST IN PARADISE                    ALI
# 17                                           Ta reine                 Angèle
# 18                  Kamia Den Miazi Me Sena Matia Mou     Giannis Ploutarhos
# 19                                         Lasse redn              Die Ärzte
#
#                                            Album  \
# 0                                        TOO BAD
# 1          Young, Wild & Free (feat. Bruno Mars)
# 2                                Onka's Big Moka
# 3                                          NDGGA
# 4                                     Exhibition
# 5                           INVU - The 3rd Album
# 6                             Mikres Fotografies
# 7                                         Voyage
# 8                             I Dinami Tou Erota
# 9   The Rubberband Man / Now That We're Together
# 10                Show Me The Money 10 Episode 3
# 11                  Good Girl Gone Bad: Reloaded
# 12                         Quartet San Francisco
# 13                                     친구로 지내자면서
# 14                                      DOWNPOUR
# 15                                          Jazz
# 16                              LOST IN PARADISE
# 17                                          Brol
# 18           Den Ine O Erotas...Pedi Tis Logikis
# 19                               Jazz ist anders
#
#                                      URI                track_id
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN  06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734  5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od  3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z  4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW  3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL  0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L  6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj  4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh  3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6  13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5  5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL  3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf  16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j  4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83  3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7  5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG  145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1  3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS  5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp  5pPPd1mWUBZLejws9xf5Sp

# %%
df_yoojin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     46 non-null     object
#  1   Artist    46 non-null     object
#  2   Album     46 non-null     object
#  3   URI       46 non-null     object
#  4   track_id  46 non-null     object
# dtypes: object(5)
# memory usage: 1.9+ KB

# %% [markdown]
# df_wadthy_sampled.head()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='582341de1c87493291783ae774754039', client_secret='a21c97ce2062459a8f257d476ed5fe97')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import time

def get_audio_features_batch(track_ids, batch_size=100):
    audio_features = []
    for i in range(0, len(track_ids), batch_size):
        batch = track_ids[i:i+batch_size]
        features = sp.audio_features(batch)
        audio_features.extend(features)
        time.sleep(1)  # Add a 1-second delay between batches to respect rate limits
    return audio_features

# %%
all_track_ids = df_yoojin['track_id'].tolist()
all_audio_features = get_audio_features_batch(all_track_ids)

# %%
audio_features_df = pd.DataFrame(all_audio_features)
result_df = pd.merge(df_yoojin, audio_features_df, left_on='track_id', right_on='id', how='left')

# %%
result_df.head(20)
# Out:
#                                                 Title                 Artist  \
# 0                               TOO BAD (prod. CarTa)            Anandelight
# 1               Young, Wild & Free (feat. Bruno Mars)             Snoop Dogg
# 2                            Dancing in the Moonlight              Toploader
# 3                                               NDGGA                 meenoi
# 4                                     Etude of Memory             Exhibition
# 5                                             Weekend                TAEYEON
# 6                                      Ah Koritsi Mou     Giannis Ploutarhos
# 7                                           Bumblebee                   ABBA
# 8                                      Den Thelo Allo     Giannis Ploutarhos
# 9                                  The Rubberband Man           The Spinners
# 10  Reset (Feat. Gaeko, Kid Milli) (Prod. CODE KUNST)                  SINCE
# 11                                         Take A Bow                Rihanna
# 12                                           Sir Duke  Quartet San Francisco
# 13                                          친구로 지내자면서          Hwang In Wook
# 14                                           DOWNPOUR                  I.O.I
# 15                Don't Stop Me Now - Remastered 2011                  Queen
# 16                                   LOST IN PARADISE                    ALI
# 17                                           Ta reine                 Angèle
# 18                  Kamia Den Miazi Me Sena Matia Mou     Giannis Ploutarhos
# 19                                         Lasse redn              Die Ärzte
#
#                                            Album  \
# 0                                        TOO BAD
# 1          Young, Wild & Free (feat. Bruno Mars)
# 2                                Onka's Big Moka
# 3                                          NDGGA
# 4                                     Exhibition
# 5                           INVU - The 3rd Album
# 6                             Mikres Fotografies
# 7                                         Voyage
# 8                             I Dinami Tou Erota
# 9   The Rubberband Man / Now That We're Together
# 10                Show Me The Money 10 Episode 3
# 11                  Good Girl Gone Bad: Reloaded
# 12                         Quartet San Francisco
# 13                                     친구로 지내자면서
# 14                                      DOWNPOUR
# 15                                          Jazz
# 16                              LOST IN PARADISE
# 17                                          Brol
# 18           Den Ine O Erotas...Pedi Tis Logikis
# 19                               Jazz ist anders
#
#                                      URI                track_id  \
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN  06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734  5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od  3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z  4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW  3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL  0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L  6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj  4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh  3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6  13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5  5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL  3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf  16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j  4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83  3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7  5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG  145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1  3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS  5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp  5pPPd1mWUBZLejws9xf5Sp
#
#     danceability  energy  key  loudness  mode  ...  liveness  valence  \
# 0          0.579   0.791    0    -5.490     0  ...    0.2070    0.619
# 1          0.715   0.655    0    -6.425     1  ...    0.1150    0.531
# 2          0.632   0.856   10    -3.463     1  ...    0.3470    0.867
# 3          0.749   0.381    8    -7.529     1  ...    0.3770    0.517
# 4          0.444   0.370    3   -13.858     1  ...    0.2940    0.121
# 5          0.740   0.854    8    -2.209     1  ...    0.2530    0.856
# 6          0.507   0.549   10    -7.027     0  ...    0.0953    0.469
# 7          0.455   0.271   10   -11.129     1  ...    0.3100    0.227
# 8          0.646   0.826   10    -3.332     0  ...    0.2940    0.588
# 9          0.801   0.446   10   -14.604     1  ...    0.0832    0.924
# 10         0.493   0.718    2    -5.098     1  ...    0.1160    0.650
# 11         0.518   0.467    9    -7.536     1  ...    0.0941    0.559
# 12         0.667   0.220    0   -13.125     1  ...    0.1050    0.770
# 13         0.413   0.455    7    -6.446     1  ...    0.3600    0.160
# 14         0.424   0.433    9    -4.073     1  ...    0.1300    0.331
# 15         0.559   0.868    5    -5.276     1  ...    0.7760    0.609
# 16         0.648   0.908    6    -3.946     0  ...    0.0772    0.734
# 17         0.668   0.440    9   -10.607     0  ...    0.0901    0.127
# 18         0.676   0.516    0    -7.206     0  ...    0.0743    0.474
# 19         0.810   0.737   11    -5.659     1  ...    0.0982    0.736
#
#       tempo            type                      id  \
# 0   165.988  audio_features  06vHdq1RN59tke4Ixq6usN
# 1    95.078  audio_features  5HQVUIKwCEXpe7JIHyY734
# 2   119.397  audio_features  3Fzlg5r1IjhLk2qRw667od
# 3   109.434  audio_features  4k4PQkx007qoo6XPbijp9z
# 4   135.862  audio_features  3YpiZu52TdVbNKExZpZAWW
# 5   114.029  audio_features  0n1jo6k1GUzyrcXW2aS0iL
# 6   104.168  audio_features  6RM4uRehk0XvKUzYO3Y93L
# 7   135.016  audio_features  4dmSIn2DxtfX1rySnUDamj
# 8   119.993  audio_features  3Su4Xx8b8ko1kGrjYs2CIh
# 9    97.894  audio_features  13Mzsb8VzRSZ5w3pM48cn6
# 10   87.649  audio_features  5oD7cKg3DRl2HFuybvVsI5
# 11   79.965  audio_features  3goSVuTt3fDYDP6kRnFwuL
# 12  106.451  audio_features  16ArKmfYyDsWqGowWt6ntf
# 13  130.933  audio_features  4hRkuqTfL00G1MWmcyAk1j
# 14  144.952  audio_features  3pMnRGNIgK0Ql19zvnjv83
# 15  156.295  audio_features  5T8EDUDqKcs6OSOwEsfqG7
# 16  121.993  audio_features  145wBbokDZTFZLFHOtZrzG
# 17  107.091  audio_features  3iXhLi33EpUfcOwasC8un1
# 18  112.835  audio_features  5ooI7eKotorrBsnJHcw5uS
# 19  132.990  audio_features  5pPPd1mWUBZLejws9xf5Sp
#
#                                      uri  \
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/06vHdq1RN59t...
# 1   https://api.spotify.com/v1/tracks/5HQVUIKwCEXp...
# 2   https://api.spotify.com/v1/tracks/3Fzlg5r1IjhL...
# 3   https://api.spotify.com/v1/tracks/4k4PQkx007qo...
# 4   https://api.spotify.com/v1/tracks/3YpiZu52TdVb...
# 5   https://api.spotify.com/v1/tracks/0n1jo6k1GUzy...
# 6   https://api.spotify.com/v1/tracks/6RM4uRehk0Xv...
# 7   https://api.spotify.com/v1/tracks/4dmSIn2DxtfX...
# 8   https://api.spotify.com/v1/tracks/3Su4Xx8b8ko1...
# 9   https://api.spotify.com/v1/tracks/13Mzsb8VzRSZ...
# 10  https://api.spotify.com/v1/tracks/5oD7cKg3DRl2...
# 11  https://api.spotify.com/v1/tracks/3goSVuTt3fDY...
# 12  https://api.spotify.com/v1/tracks/16ArKmfYyDsW...
# 13  https://api.spotify.com/v1/tracks/4hRkuqTfL00G...
# 14  https://api.spotify.com/v1/tracks/3pMnRGNIgK0Q...
# 15  https://api.spotify.com/v1/tracks/5T8EDUDqKcs6...
# 16  https://api.spotify.com/v1/tracks/145wBbokDZTF...
# 17  https://api.spotify.com/v1/tracks/3iXhLi33EpUf...
# 18  https://api.spotify.com/v1/tracks/5ooI7eKotorr...
# 19  https://api.spotify.com/v1/tracks/5pPPd1mWUBZL...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/06vH...      213976
# 1   https://api.spotify.com/v1/audio-analysis/5HQV...      207333
# 2   https://api.spotify.com/v1/audio-analysis/3Fzl...      232693
# 3   https://api.spotify.com/v1/audio-analysis/4k4P...      175412
# 4   https://api.spotify.com/v1/audio-analysis/3Ypi...      313107
# 5   https://api.spotify.com/v1/audio-analysis/0n1j...      233413
# 6   https://api.spotify.com/v1/audio-analysis/6RM4...      233400
# 7   https://api.spotify.com/v1/audio-analysis/4dmS...      237467
# 8   https://api.spotify.com/v1/audio-analysis/3Su4...      215293
# 9   https://api.spotify.com/v1/audio-analysis/13Mz...      213000
# 10  https://api.spotify.com/v1/audio-analysis/5oD7...      257973
# 11  https://api.spotify.com/v1/audio-analysis/3goS...      229413
# 12  https://api.spotify.com/v1/audio-analysis/16Ar...      168653
# 13  https://api.spotify.com/v1/audio-analysis/4hRk...      235000
# 14  https://api.spotify.com/v1/audio-analysis/3pMn...      234259
# 15  https://api.spotify.com/v1/audio-analysis/5T8E...      209413
# 16  https://api.spotify.com/v1/audio-analysis/145w...      328960
# 17  https://api.spotify.com/v1/audio-analysis/3iXh...      213200
# 18  https://api.spotify.com/v1/audio-analysis/5ooI...      250973
# 19  https://api.spotify.com/v1/audio-analysis/5pPP...      169680
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               3
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
#
# [20 rows x 23 columns]

# %%
result_df['MBTI'] = 'ENFP'

# %%
result_df.head(20)
# Out:
#                                                 Title                 Artist  \
# 0                               TOO BAD (prod. CarTa)            Anandelight
# 1               Young, Wild & Free (feat. Bruno Mars)             Snoop Dogg
# 2                            Dancing in the Moonlight              Toploader
# 3                                               NDGGA                 meenoi
# 4                                     Etude of Memory             Exhibition
# 5                                             Weekend                TAEYEON
# 6                                      Ah Koritsi Mou     Giannis Ploutarhos
# 7                                           Bumblebee                   ABBA
# 8                                      Den Thelo Allo     Giannis Ploutarhos
# 9                                  The Rubberband Man           The Spinners
# 10  Reset (Feat. Gaeko, Kid Milli) (Prod. CODE KUNST)                  SINCE
# 11                                         Take A Bow                Rihanna
# 12                                           Sir Duke  Quartet San Francisco
# 13                                          친구로 지내자면서          Hwang In Wook
# 14                                           DOWNPOUR                  I.O.I
# 15                Don't Stop Me Now - Remastered 2011                  Queen
# 16                                   LOST IN PARADISE                    ALI
# 17                                           Ta reine                 Angèle
# 18                  Kamia Den Miazi Me Sena Matia Mou     Giannis Ploutarhos
# 19                                         Lasse redn              Die Ärzte
#
#                                            Album  \
# 0                                        TOO BAD
# 1          Young, Wild & Free (feat. Bruno Mars)
# 2                                Onka's Big Moka
# 3                                          NDGGA
# 4                                     Exhibition
# 5                           INVU - The 3rd Album
# 6                             Mikres Fotografies
# 7                                         Voyage
# 8                             I Dinami Tou Erota
# 9   The Rubberband Man / Now That We're Together
# 10                Show Me The Money 10 Episode 3
# 11                  Good Girl Gone Bad: Reloaded
# 12                         Quartet San Francisco
# 13                                     친구로 지내자면서
# 14                                      DOWNPOUR
# 15                                          Jazz
# 16                              LOST IN PARADISE
# 17                                          Brol
# 18           Den Ine O Erotas...Pedi Tis Logikis
# 19                               Jazz ist anders
#
#                                      URI                track_id  \
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN  06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734  5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od  3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z  4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW  3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL  0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L  6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj  4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh  3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6  13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5  5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL  3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf  16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j  4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83  3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7  5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG  145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1  3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS  5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp  5pPPd1mWUBZLejws9xf5Sp
#
#     danceability  energy  key  loudness  mode  ...  valence    tempo  \
# 0          0.579   0.791    0    -5.490     0  ...    0.619  165.988
# 1          0.715   0.655    0    -6.425     1  ...    0.531   95.078
# 2          0.632   0.856   10    -3.463     1  ...    0.867  119.397
# 3          0.749   0.381    8    -7.529     1  ...    0.517  109.434
# 4          0.444   0.370    3   -13.858     1  ...    0.121  135.862
# 5          0.740   0.854    8    -2.209     1  ...    0.856  114.029
# 6          0.507   0.549   10    -7.027     0  ...    0.469  104.168
# 7          0.455   0.271   10   -11.129     1  ...    0.227  135.016
# 8          0.646   0.826   10    -3.332     0  ...    0.588  119.993
# 9          0.801   0.446   10   -14.604     1  ...    0.924   97.894
# 10         0.493   0.718    2    -5.098     1  ...    0.650   87.649
# 11         0.518   0.467    9    -7.536     1  ...    0.559   79.965
# 12         0.667   0.220    0   -13.125     1  ...    0.770  106.451
# 13         0.413   0.455    7    -6.446     1  ...    0.160  130.933
# 14         0.424   0.433    9    -4.073     1  ...    0.331  144.952
# 15         0.559   0.868    5    -5.276     1  ...    0.609  156.295
# 16         0.648   0.908    6    -3.946     0  ...    0.734  121.993
# 17         0.668   0.440    9   -10.607     0  ...    0.127  107.091
# 18         0.676   0.516    0    -7.206     0  ...    0.474  112.835
# 19         0.810   0.737   11    -5.659     1  ...    0.736  132.990
#
#               type                      id  \
# 0   audio_features  06vHdq1RN59tke4Ixq6usN
# 1   audio_features  5HQVUIKwCEXpe7JIHyY734
# 2   audio_features  3Fzlg5r1IjhLk2qRw667od
# 3   audio_features  4k4PQkx007qoo6XPbijp9z
# 4   audio_features  3YpiZu52TdVbNKExZpZAWW
# 5   audio_features  0n1jo6k1GUzyrcXW2aS0iL
# 6   audio_features  6RM4uRehk0XvKUzYO3Y93L
# 7   audio_features  4dmSIn2DxtfX1rySnUDamj
# 8   audio_features  3Su4Xx8b8ko1kGrjYs2CIh
# 9   audio_features  13Mzsb8VzRSZ5w3pM48cn6
# 10  audio_features  5oD7cKg3DRl2HFuybvVsI5
# 11  audio_features  3goSVuTt3fDYDP6kRnFwuL
# 12  audio_features  16ArKmfYyDsWqGowWt6ntf
# 13  audio_features  4hRkuqTfL00G1MWmcyAk1j
# 14  audio_features  3pMnRGNIgK0Ql19zvnjv83
# 15  audio_features  5T8EDUDqKcs6OSOwEsfqG7
# 16  audio_features  145wBbokDZTFZLFHOtZrzG
# 17  audio_features  3iXhLi33EpUfcOwasC8un1
# 18  audio_features  5ooI7eKotorrBsnJHcw5uS
# 19  audio_features  5pPPd1mWUBZLejws9xf5Sp
#
#                                      uri  \
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/06vHdq1RN59t...
# 1   https://api.spotify.com/v1/tracks/5HQVUIKwCEXp...
# 2   https://api.spotify.com/v1/tracks/3Fzlg5r1IjhL...
# 3   https://api.spotify.com/v1/tracks/4k4PQkx007qo...
# 4   https://api.spotify.com/v1/tracks/3YpiZu52TdVb...
# 5   https://api.spotify.com/v1/tracks/0n1jo6k1GUzy...
# 6   https://api.spotify.com/v1/tracks/6RM4uRehk0Xv...
# 7   https://api.spotify.com/v1/tracks/4dmSIn2DxtfX...
# 8   https://api.spotify.com/v1/tracks/3Su4Xx8b8ko1...
# 9   https://api.spotify.com/v1/tracks/13Mzsb8VzRSZ...
# 10  https://api.spotify.com/v1/tracks/5oD7cKg3DRl2...
# 11  https://api.spotify.com/v1/tracks/3goSVuTt3fDY...
# 12  https://api.spotify.com/v1/tracks/16ArKmfYyDsW...
# 13  https://api.spotify.com/v1/tracks/4hRkuqTfL00G...
# 14  https://api.spotify.com/v1/tracks/3pMnRGNIgK0Q...
# 15  https://api.spotify.com/v1/tracks/5T8EDUDqKcs6...
# 16  https://api.spotify.com/v1/tracks/145wBbokDZTF...
# 17  https://api.spotify.com/v1/tracks/3iXhLi33EpUf...
# 18  https://api.spotify.com/v1/tracks/5ooI7eKotorr...
# 19  https://api.spotify.com/v1/tracks/5pPPd1mWUBZL...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/06vH...      213976
# 1   https://api.spotify.com/v1/audio-analysis/5HQV...      207333
# 2   https://api.spotify.com/v1/audio-analysis/3Fzl...      232693
# 3   https://api.spotify.com/v1/audio-analysis/4k4P...      175412
# 4   https://api.spotify.com/v1/audio-analysis/3Ypi...      313107
# 5   https://api.spotify.com/v1/audio-analysis/0n1j...      233413
# 6   https://api.spotify.com/v1/audio-analysis/6RM4...      233400
# 7   https://api.spotify.com/v1/audio-analysis/4dmS...      237467
# 8   https://api.spotify.com/v1/audio-analysis/3Su4...      215293
# 9   https://api.spotify.com/v1/audio-analysis/13Mz...      213000
# 10  https://api.spotify.com/v1/audio-analysis/5oD7...      257973
# 11  https://api.spotify.com/v1/audio-analysis/3goS...      229413
# 12  https://api.spotify.com/v1/audio-analysis/16Ar...      168653
# 13  https://api.spotify.com/v1/audio-analysis/4hRk...      235000
# 14  https://api.spotify.com/v1/audio-analysis/3pMn...      234259
# 15  https://api.spotify.com/v1/audio-analysis/5T8E...      209413
# 16  https://api.spotify.com/v1/audio-analysis/145w...      328960
# 17  https://api.spotify.com/v1/audio-analysis/3iXh...      213200
# 18  https://api.spotify.com/v1/audio-analysis/5ooI...      250973
# 19  https://api.spotify.com/v1/audio-analysis/5pPP...      169680
#
#    time_signature  MBTI
# 0               4  ENFP
# 1               4  ENFP
# 2               4  ENFP
# 3               4  ENFP
# 4               4  ENFP
# 5               4  ENFP
# 6               4  ENFP
# 7               3  ENFP
# 8               4  ENFP
# 9               4  ENFP
# 10              4  ENFP
# 11              4  ENFP
# 12              4  ENFP
# 13              4  ENFP
# 14              4  ENFP
# 15              4  ENFP
# 16              4  ENFP
# 17              4  ENFP
# 18              4  ENFP
# 19              4  ENFP
#
# [20 rows x 24 columns]

# %%
# Save the extended DataFrame
result_df.to_csv('extended_songs_yoojin.csv', index=False)
