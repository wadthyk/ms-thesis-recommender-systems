# %% [markdown]
# # Extracting Disliked Songs of a User using streaming history

# %%
# extracting the streaming history as JSON and save relevant columns as Pandas DF

import json
import pandas as pd

# Read the JSON file
with open('/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/03_Data_Moni_ISFP/Spotify Account Data/StreamingHistory_music_0.json', 'r') as file:
    data = json.load(file)

# Extract the required fields
extracted_data = [
    {
        'artistName': item['artistName'],
        'trackName': item['trackName'],
        'msPlayed': item['msPlayed']
    }
    for item in data
]

# Create a pandas DataFrame
df = pd.DataFrame(extracted_data)

# Display the first few rows of the DataFrame
print(df.head())

# Save the DataFrame to a CSV file (optional)
# df.to_csv('streaming_history.csv', index=False)
# Out:
#             artistName                      trackName  msPlayed
# 0                 D.O.                    That's okay    221373
# 1         Jason Derulo  Vertigo (feat. Jordin Sparks)    233173
# 2  Panic! At The Disco              House of Memories    208706
# 3              Charice           Pyramid (feat. Iyaz)    187584
# 4              Charice           Pyramid (feat. Iyaz)      6122

# %%
df.head(10)
# Out:
#             artistName                      trackName  msPlayed
# 0                 D.O.                    That's okay    221373
# 1         Jason Derulo  Vertigo (feat. Jordin Sparks)    233173
# 2  Panic! At The Disco              House of Memories    208706
# 3              Charice           Pyramid (feat. Iyaz)    187584
# 4              Charice           Pyramid (feat. Iyaz)      6122
# 5           Ed Sheeran                     Bad Habits    230746
# 6         Jason Derulo                 The Other Side    226986
# 7              SLANDER                   Love Is Gone    256042
# 8  Kurt Hugo Schneider              I Really Like You    191555
# 9         Jason Derulo  Vertigo (feat. Jordin Sparks)    233173

# %%
df.shape
# Out:
# (3884, 3)

# %%
# creating a "like_dislike" column out of dataframe based on msPlayed (if <30000 then 0 / dislike else 1 / like)
df['like_dislike'] = (df['msPlayed'] > 30000).astype(int)

# Filter for disliked songs (like_dislike = 0)
df_dislike = df[df['like_dislike'] == 0]

# Filter for liked songs (like_dislike = 1)
df_like = df[df['like_dislike'] == 1]

# Remove entries where trackName is "Unknown Track"
df_dislike = df_dislike[df_dislike['trackName'] != "Unknown Track"]

# Drop duplicate values
df_dislike = df_dislike.drop_duplicates(subset='trackName', keep=False)

# getting a random sample of 200 entries out of the 
df_dislike_sampled = df_dislike.sample(n=200 , random_state=42)

# %%
df_dislike.shape
# Out:
# (116, 4)

# %%
df_dislike_sampled.shape
# Out:
# (116, 4)

# %%
df_dislike_sampled.duplicated().sum()
# Out:
# 0

# %%
# getting Song URI based on the artistName and trackName

import pandas as pd
import requests
import base64

# Spotify API credentials
client_id = '582341de1c87493291783ae774754039'
client_secret = 'a21c97ce2062459a8f257d476ed5fe97'

# Function to get access token
def get_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()
    auth_data = {'grant_type': 'client_credentials'}
    auth_response = requests.post(auth_url, headers={'Authorization': f'Basic {auth_header}'}, data=auth_data)
    return auth_response.json()['access_token']

# Function to search for a track and get its URI
def get_track_uri(artist_name, track_name, access_token):
    search_url = 'https://api.spotify.com/v1/search'
    query = f"track:{track_name} artist:{artist_name}"
    search_params = {
        'q': query,
        'type': 'track',
        'limit': 1
    }
    search_response = requests.get(search_url, headers={'Authorization': f'Bearer {access_token}'}, params=search_params)

    if search_response.status_code == 200:
        results = search_response.json()
        if results['tracks']['items']:
            return results['tracks']['items'][0]['uri']
    return None

# Get access token
access_token = get_access_token(client_id, client_secret)

# Function to apply to each row of the DataFrame
def get_uri_for_row(row):
    return get_track_uri(row['artistName'], row['trackName'], access_token)

# Apply the function to each row and create a new 'track_uri' column
df_dislike_sampled['track_uri'] = df_dislike_sampled.apply(get_uri_for_row, axis=1)

# Display the first few rows of the updated DataFrame
print(df_dislike_sampled[['artistName', 'trackName', 'track_uri']].head())

# Optionally, save the updated DataFrame to a CSV file
# df_dislike.to_csv('disliked_songs_with_uris.csv', index=False)
# Out:
#          artistName            trackName                             track_uri
# 2740   Mark Forster        Wir Sind Groß  spotify:track:7AraSdlKIOoPCLRKkI3WjP
# 308             陈令韬            输入法打可爱按第五  spotify:track:53zetdmdcvQnruSWhLTwFP
# 1241  Lewis Capaldi  How I'm Feeling Now  spotify:track:5AGS8VxsLyHQOWz0ZTuwIN
# 1112          LeeHi              BREATHE  spotify:track:6G4z9WbxyEeWdEQTfShACT
# 467     James Blunt                 1973  spotify:track:1BV0m40U0M4t1SLIsDnwZl

# %%
# dropping 2 columns
df_dislike_sampled_final = df_dislike_sampled.drop(['msPlayed', 'like_dislike'], axis=1)

# %%
# splitting track URI column to get track_id separately
df_dislike_sampled_final['track_id'] = df_dislike_sampled_final.iloc[:, 2].str.split(':').str.get(-1)

# %%
df_dislike_sampled_final.head(10)
# Out:
#          artistName                     trackName  \
# 2740   Mark Forster                 Wir Sind Groß
# 308             陈令韬                     输入法打可爱按第五
# 1241  Lewis Capaldi           How I'm Feeling Now
# 1112          LeeHi                       BREATHE
# 467     James Blunt                          1973
# 1296   Jason Derulo           Don't Wanna Go Home
# 3665  Wincent Weiss                          1993
# 1022   Mark Forster               Drei Uhr Nachts
# 2377   Paloma Faith  Only Love Can Hurt Like This
# 472             BTS       Epilogue: Young Forever
#
#                                  track_uri                track_id
# 2740  spotify:track:7AraSdlKIOoPCLRKkI3WjP  7AraSdlKIOoPCLRKkI3WjP
# 308   spotify:track:53zetdmdcvQnruSWhLTwFP  53zetdmdcvQnruSWhLTwFP
# 1241  spotify:track:5AGS8VxsLyHQOWz0ZTuwIN  5AGS8VxsLyHQOWz0ZTuwIN
# 1112  spotify:track:6G4z9WbxyEeWdEQTfShACT  6G4z9WbxyEeWdEQTfShACT
# 467   spotify:track:1BV0m40U0M4t1SLIsDnwZl  1BV0m40U0M4t1SLIsDnwZl
# 1296  spotify:track:7rGjz05rxd9MaXUAo7F4kb  7rGjz05rxd9MaXUAo7F4kb
# 3665  spotify:track:3E8qvYDyhKat3qGhmovygJ  3E8qvYDyhKat3qGhmovygJ
# 1022  spotify:track:58GxgFEG5uHc9oMhofuuIP  58GxgFEG5uHc9oMhofuuIP
# 2377  spotify:track:62ke5zFUJN6RvtXZgVH0F8  62ke5zFUJN6RvtXZgVH0F8
# 472   spotify:track:6BskTMfDjXVzeqQHOau5Vi  6BskTMfDjXVzeqQHOau5Vi

# %%
# Drop duplicate values
df_dislike_sampled_final = df_dislike_sampled_final.drop_duplicates()

# %%
df_dislike_sampled_final.duplicated().sum()
# Out:
# 0

# %%
# dropping null values in the track_uri column
df_dislike_sampled_final = df_dislike_sampled_final.dropna()

# %%
df_dislike_sampled_final.shape
# Out:
# (109, 4)

# %%
df_dislike_sampled_final.head(20)
# Out:
#           artistName                             trackName  \
# 2740    Mark Forster                         Wir Sind Groß
# 308              陈令韬                             输入法打可爱按第五
# 1241   Lewis Capaldi                   How I'm Feeling Now
# 1112           LeeHi                               BREATHE
# 467      James Blunt                                  1973
# 1296    Jason Derulo                   Don't Wanna Go Home
# 3665   Wincent Weiss                                  1993
# 1022    Mark Forster                       Drei Uhr Nachts
# 2377    Paloma Faith          Only Love Can Hurt Like This
# 472              BTS               Epilogue: Young Forever
# 1263     Kim Tae Woo                                  어머님께
# 677      Tones And I                          Dance Monkey
# 1528      Jason Chen                             Invisible
# 513             D.O.                              I'm Fine
# 295      Gabry Ponte  Call Me (with R3HAB & Timmy Trumpet)
# 1944            10CM                             Phonecert
# 2747       Alex Goot                              Umbrella
# 3652            Sido                       Tausend Tattoos
# 3311             BTS                              Epiphany
# 2959  Sunrise Avenue                    Fairytale Gone Bad
#
#                                  track_uri                track_id
# 2740  spotify:track:7AraSdlKIOoPCLRKkI3WjP  7AraSdlKIOoPCLRKkI3WjP
# 308   spotify:track:53zetdmdcvQnruSWhLTwFP  53zetdmdcvQnruSWhLTwFP
# 1241  spotify:track:5AGS8VxsLyHQOWz0ZTuwIN  5AGS8VxsLyHQOWz0ZTuwIN
# 1112  spotify:track:6G4z9WbxyEeWdEQTfShACT  6G4z9WbxyEeWdEQTfShACT
# 467   spotify:track:1BV0m40U0M4t1SLIsDnwZl  1BV0m40U0M4t1SLIsDnwZl
# 1296  spotify:track:7rGjz05rxd9MaXUAo7F4kb  7rGjz05rxd9MaXUAo7F4kb
# 3665  spotify:track:3E8qvYDyhKat3qGhmovygJ  3E8qvYDyhKat3qGhmovygJ
# 1022  spotify:track:58GxgFEG5uHc9oMhofuuIP  58GxgFEG5uHc9oMhofuuIP
# 2377  spotify:track:62ke5zFUJN6RvtXZgVH0F8  62ke5zFUJN6RvtXZgVH0F8
# 472   spotify:track:6BskTMfDjXVzeqQHOau5Vi  6BskTMfDjXVzeqQHOau5Vi
# 1263  spotify:track:0o1OM5u467bWgysjNKIpY0  0o1OM5u467bWgysjNKIpY0
# 677   spotify:track:2XU0oxnq2qxCpomAAuJY8K  2XU0oxnq2qxCpomAAuJY8K
# 1528  spotify:track:2wXJfz8R8p9igLjM5sBkkh  2wXJfz8R8p9igLjM5sBkkh
# 513   spotify:track:7IDoxdASgrwumbCuX8E58s  7IDoxdASgrwumbCuX8E58s
# 295   spotify:track:1dt220OBbkTsYz1NLVKIaw  1dt220OBbkTsYz1NLVKIaw
# 1944  spotify:track:5Sh2pJT3VWTvkQOXPAaRiC  5Sh2pJT3VWTvkQOXPAaRiC
# 2747  spotify:track:7tCC6GEAhS5nIrd3ZahW0n  7tCC6GEAhS5nIrd3ZahW0n
# 3652  spotify:track:1rGZd7EVl4aOClpzDLNPwy  1rGZd7EVl4aOClpzDLNPwy
# 3311  spotify:track:6L88EH68XwlaXwvChlTS41  6L88EH68XwlaXwvChlTS41
# 2959  spotify:track:2rXW2yxuRJoZhAZeowgomh  2rXW2yxuRJoZhAZeowgomh

# %%
df_dislike_sampled_final['track_id'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### extracting audio_features via Spotify API

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id='582341de1c87493291783ae774754039', client_secret='a21c97ce2062459a8f257d476ed5fe97')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import time

def get_audio_features_batch(track_ids, batch_size=100):
    audio_features = []
    for i in range(0, len(track_ids), batch_size):
        batch = track_ids[i:i+batch_size]
        features = sp.audio_features(batch)
        audio_features.extend(features)
        time.sleep(1)  # Add a 1-second delay between batches to respect rate limits
    return audio_features

# %%
all_track_ids = df_dislike_sampled_final['track_id'].tolist()
all_audio_features = get_audio_features_batch(all_track_ids)

# %%
audio_features_df = pd.DataFrame(all_audio_features)
result_df = pd.merge(df_dislike_sampled_final, audio_features_df, left_on='track_id', right_on='id', how='left')

# %%
result_df.shape
# Out:
# (109, 22)

# %%
result_df.drop_duplicates()
# Out:
#         artistName                                         trackName  \
# 0     Mark Forster                                     Wir Sind Groß
# 1              陈令韬                                         输入法打可爱按第五
# 2    Lewis Capaldi                               How I'm Feeling Now
# 3            LeeHi                                           BREATHE
# 4      James Blunt                                              1973
# ..             ...                                               ...
# 104     Katy Perry                                   Unconditionally
# 105      SEVENTEEN                                      Left & Right
# 106     Tyler Ward  I Don't Wanna Live Forever (Fifty Shades Darker)
# 107          Train                        Drops of Jupiter (Tell Me)
# 108     Jason Chen                                      Time Machine
#
#                                 track_uri                track_id  \
# 0    spotify:track:7AraSdlKIOoPCLRKkI3WjP  7AraSdlKIOoPCLRKkI3WjP
# 1    spotify:track:53zetdmdcvQnruSWhLTwFP  53zetdmdcvQnruSWhLTwFP
# 2    spotify:track:5AGS8VxsLyHQOWz0ZTuwIN  5AGS8VxsLyHQOWz0ZTuwIN
# 3    spotify:track:6G4z9WbxyEeWdEQTfShACT  6G4z9WbxyEeWdEQTfShACT
# 4    spotify:track:1BV0m40U0M4t1SLIsDnwZl  1BV0m40U0M4t1SLIsDnwZl
# ..                                    ...                     ...
# 104  spotify:track:009ImBOrIUlWgla8U05RAC  009ImBOrIUlWgla8U05RAC
# 105  spotify:track:065yxZRBAsenRLZacB1uc2  065yxZRBAsenRLZacB1uc2
# 106  spotify:track:1etANXelRasvdwGDDj0reR  1etANXelRasvdwGDDj0reR
# 107  spotify:track:2hKdd3qO7cWr2Jo0Bcs0MA  2hKdd3qO7cWr2Jo0Bcs0MA
# 108  spotify:track:1bDa17abFs51SRHhvXQyPO  1bDa17abFs51SRHhvXQyPO
#
#      danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0           0.624   0.687    7    -6.403     0       0.1720  ...    0.1120
# 1           0.550   0.527    7    -7.682     1       0.0268  ...    0.1180
# 2           0.685   0.435    0    -3.979     1       0.0277  ...    0.1900
# 3           0.616   0.251    8    -8.454     1       0.0380  ...    0.0790
# 4           0.720   0.668    9    -7.928     1       0.0269  ...    0.0789
# ..            ...     ...  ...       ...   ...          ...  ...       ...
# 104         0.432   0.725    7    -4.862     1       0.0431  ...    0.2080
# 105         0.725   0.823    6    -3.868     0       0.1150  ...    0.1040
# 106         0.787   0.403    0   -11.989     1       0.0330  ...    0.1310
# 107         0.481   0.638    0    -5.862     1       0.0276  ...    0.1540
# 108         0.471   0.600    0    -6.700     1       0.0290  ...    0.1730
#
#      valence    tempo            type                      id  \
# 0      0.407   86.038  audio_features  7AraSdlKIOoPCLRKkI3WjP
# 1      0.330  143.910  audio_features  53zetdmdcvQnruSWhLTwFP
# 2      0.398  102.910  audio_features  5AGS8VxsLyHQOWz0ZTuwIN
# 3      0.356  123.802  audio_features  6G4z9WbxyEeWdEQTfShACT
# 4      0.769  123.005  audio_features  1BV0m40U0M4t1SLIsDnwZl
# ..       ...      ...             ...                     ...
# 104    0.353  128.902  audio_features  009ImBOrIUlWgla8U05RAC
# 105    0.958  149.994  audio_features  065yxZRBAsenRLZacB1uc2
# 106    0.264  118.043  audio_features  1etANXelRasvdwGDDj0reR
# 107    0.497   79.064  audio_features  2hKdd3qO7cWr2Jo0Bcs0MA
# 108    0.474   85.219  audio_features  1bDa17abFs51SRHhvXQyPO
#
#                                       uri  \
# 0    spotify:track:7AraSdlKIOoPCLRKkI3WjP
# 1    spotify:track:53zetdmdcvQnruSWhLTwFP
# 2    spotify:track:5AGS8VxsLyHQOWz0ZTuwIN
# 3    spotify:track:6G4z9WbxyEeWdEQTfShACT
# 4    spotify:track:1BV0m40U0M4t1SLIsDnwZl
# ..                                    ...
# 104  spotify:track:009ImBOrIUlWgla8U05RAC
# 105  spotify:track:065yxZRBAsenRLZacB1uc2
# 106  spotify:track:1etANXelRasvdwGDDj0reR
# 107  spotify:track:2hKdd3qO7cWr2Jo0Bcs0MA
# 108  spotify:track:1bDa17abFs51SRHhvXQyPO
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/7AraSdlKIOoP...
# 1    https://api.spotify.com/v1/tracks/53zetdmdcvQn...
# 2    https://api.spotify.com/v1/tracks/5AGS8VxsLyHQ...
# 3    https://api.spotify.com/v1/tracks/6G4z9WbxyEeW...
# 4    https://api.spotify.com/v1/tracks/1BV0m40U0M4t...
# ..                                                 ...
# 104  https://api.spotify.com/v1/tracks/009ImBOrIUlW...
# 105  https://api.spotify.com/v1/tracks/065yxZRBAsen...
# 106  https://api.spotify.com/v1/tracks/1etANXelRasv...
# 107  https://api.spotify.com/v1/tracks/2hKdd3qO7cWr...
# 108  https://api.spotify.com/v1/tracks/1bDa17abFs51...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/7Ara...      204760
# 1    https://api.spotify.com/v1/audio-analysis/53ze...      229686
# 2    https://api.spotify.com/v1/audio-analysis/5AGS...      226440
# 3    https://api.spotify.com/v1/audio-analysis/6G4z...      288915
# 4    https://api.spotify.com/v1/audio-analysis/1BV0...      280027
# ..                                                 ...         ...
# 104  https://api.spotify.com/v1/audio-analysis/009I...      228879
# 105  https://api.spotify.com/v1/audio-analysis/065y...      201773
# 106  https://api.spotify.com/v1/audio-analysis/1etA...      222352
# 107  https://api.spotify.com/v1/audio-analysis/2hKd...      259933
# 108  https://api.spotify.com/v1/audio-analysis/1bDa...      187590
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 104              4
# 105              4
# 106              4
# 107              4
# 108              4
#
# [109 rows x 22 columns]

# %%
result_df.head(20)
# Out:
#         artistName                             trackName  \
# 0     Mark Forster                         Wir Sind Groß
# 1              陈令韬                             输入法打可爱按第五
# 2    Lewis Capaldi                   How I'm Feeling Now
# 3            LeeHi                               BREATHE
# 4      James Blunt                                  1973
# 5     Jason Derulo                   Don't Wanna Go Home
# 6    Wincent Weiss                                  1993
# 7     Mark Forster                       Drei Uhr Nachts
# 8     Paloma Faith          Only Love Can Hurt Like This
# 9              BTS               Epilogue: Young Forever
# 10     Kim Tae Woo                                  어머님께
# 11     Tones And I                          Dance Monkey
# 12      Jason Chen                             Invisible
# 13            D.O.                              I'm Fine
# 14     Gabry Ponte  Call Me (with R3HAB & Timmy Trumpet)
# 15            10CM                             Phonecert
# 16       Alex Goot                              Umbrella
# 17            Sido                       Tausend Tattoos
# 18             BTS                              Epiphany
# 19  Sunrise Avenue                    Fairytale Gone Bad
#
#                                track_uri                track_id  \
# 0   spotify:track:7AraSdlKIOoPCLRKkI3WjP  7AraSdlKIOoPCLRKkI3WjP
# 1   spotify:track:53zetdmdcvQnruSWhLTwFP  53zetdmdcvQnruSWhLTwFP
# 2   spotify:track:5AGS8VxsLyHQOWz0ZTuwIN  5AGS8VxsLyHQOWz0ZTuwIN
# 3   spotify:track:6G4z9WbxyEeWdEQTfShACT  6G4z9WbxyEeWdEQTfShACT
# 4   spotify:track:1BV0m40U0M4t1SLIsDnwZl  1BV0m40U0M4t1SLIsDnwZl
# 5   spotify:track:7rGjz05rxd9MaXUAo7F4kb  7rGjz05rxd9MaXUAo7F4kb
# 6   spotify:track:3E8qvYDyhKat3qGhmovygJ  3E8qvYDyhKat3qGhmovygJ
# 7   spotify:track:58GxgFEG5uHc9oMhofuuIP  58GxgFEG5uHc9oMhofuuIP
# 8   spotify:track:62ke5zFUJN6RvtXZgVH0F8  62ke5zFUJN6RvtXZgVH0F8
# 9   spotify:track:6BskTMfDjXVzeqQHOau5Vi  6BskTMfDjXVzeqQHOau5Vi
# 10  spotify:track:0o1OM5u467bWgysjNKIpY0  0o1OM5u467bWgysjNKIpY0
# 11  spotify:track:2XU0oxnq2qxCpomAAuJY8K  2XU0oxnq2qxCpomAAuJY8K
# 12  spotify:track:2wXJfz8R8p9igLjM5sBkkh  2wXJfz8R8p9igLjM5sBkkh
# 13  spotify:track:7IDoxdASgrwumbCuX8E58s  7IDoxdASgrwumbCuX8E58s
# 14  spotify:track:1dt220OBbkTsYz1NLVKIaw  1dt220OBbkTsYz1NLVKIaw
# 15  spotify:track:5Sh2pJT3VWTvkQOXPAaRiC  5Sh2pJT3VWTvkQOXPAaRiC
# 16  spotify:track:7tCC6GEAhS5nIrd3ZahW0n  7tCC6GEAhS5nIrd3ZahW0n
# 17  spotify:track:1rGZd7EVl4aOClpzDLNPwy  1rGZd7EVl4aOClpzDLNPwy
# 18  spotify:track:6L88EH68XwlaXwvChlTS41  6L88EH68XwlaXwvChlTS41
# 19  spotify:track:2rXW2yxuRJoZhAZeowgomh  2rXW2yxuRJoZhAZeowgomh
#
#     danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0          0.624   0.687    7    -6.403     0       0.1720  ...    0.1120
# 1          0.550   0.527    7    -7.682     1       0.0268  ...    0.1180
# 2          0.685   0.435    0    -3.979     1       0.0277  ...    0.1900
# 3          0.616   0.251    8    -8.454     1       0.0380  ...    0.0790
# 4          0.720   0.668    9    -7.928     1       0.0269  ...    0.0789
# 5          0.623   0.874    2    -4.296     0       0.0506  ...    0.1790
# 6          0.553   0.315    0   -10.082     1       0.0329  ...    0.1070
# 7          0.663   0.673    8    -7.031     1       0.1190  ...    0.1910
# 8          0.566   0.885    8    -4.528     1       0.0818  ...    0.3340
# 9          0.606   0.815    5    -3.818     0       0.2320  ...    0.1190
# 10         0.403   0.495    4    -7.114     1       0.0644  ...    0.4740
# 11         0.824   0.588    6    -6.400     0       0.0924  ...    0.1490
# 12         0.709   0.568    0    -6.786     1       0.0308  ...    0.1550
# 13         0.411   0.818   10    -6.777     0       0.0735  ...    0.1090
# 14         0.398   0.956    2    -4.429     1       0.3290  ...    0.1420
# 15         0.858   0.481    9    -3.649     1       0.1040  ...    0.1280
# 16         0.547   0.602    1    -6.837     1       0.0533  ...    0.0928
# 17         0.652   0.818   11    -4.223     1       0.2210  ...    0.2340
# 18         0.508   0.559    2    -6.366     0       0.0276  ...    0.1310
# 19         0.693   0.607   10    -6.866     0       0.0398  ...    0.0951
#
#     valence    tempo            type                      id  \
# 0     0.407   86.038  audio_features  7AraSdlKIOoPCLRKkI3WjP
# 1     0.330  143.910  audio_features  53zetdmdcvQnruSWhLTwFP
# 2     0.398  102.910  audio_features  5AGS8VxsLyHQOWz0ZTuwIN
# 3     0.356  123.802  audio_features  6G4z9WbxyEeWdEQTfShACT
# 4     0.769  123.005  audio_features  1BV0m40U0M4t1SLIsDnwZl
# 5     0.682  127.992  audio_features  7rGjz05rxd9MaXUAo7F4kb
# 6     0.116   92.717  audio_features  3E8qvYDyhKat3qGhmovygJ
# 7     0.759  164.817  audio_features  58GxgFEG5uHc9oMhofuuIP
# 8     0.304   90.990  audio_features  62ke5zFUJN6RvtXZgVH0F8
# 9     0.386   88.054  audio_features  6BskTMfDjXVzeqQHOau5Vi
# 10    0.153  138.170  audio_features  0o1OM5u467bWgysjNKIpY0
# 11    0.513   98.027  audio_features  2XU0oxnq2qxCpomAAuJY8K
# 12    0.278  114.969  audio_features  2wXJfz8R8p9igLjM5sBkkh
# 13    0.349  190.009  audio_features  7IDoxdASgrwumbCuX8E58s
# 14    0.269  106.581  audio_features  1dt220OBbkTsYz1NLVKIaw
# 15    0.773  107.960  audio_features  5Sh2pJT3VWTvkQOXPAaRiC
# 16    0.646  174.080  audio_features  7tCC6GEAhS5nIrd3ZahW0n
# 17    0.373   92.246  audio_features  1rGZd7EVl4aOClpzDLNPwy
# 18    0.329  135.866  audio_features  6L88EH68XwlaXwvChlTS41
# 19    0.665  138.024  audio_features  2rXW2yxuRJoZhAZeowgomh
#
#                                      uri  \
# 0   spotify:track:7AraSdlKIOoPCLRKkI3WjP
# 1   spotify:track:53zetdmdcvQnruSWhLTwFP
# 2   spotify:track:5AGS8VxsLyHQOWz0ZTuwIN
# 3   spotify:track:6G4z9WbxyEeWdEQTfShACT
# 4   spotify:track:1BV0m40U0M4t1SLIsDnwZl
# 5   spotify:track:7rGjz05rxd9MaXUAo7F4kb
# 6   spotify:track:3E8qvYDyhKat3qGhmovygJ
# 7   spotify:track:58GxgFEG5uHc9oMhofuuIP
# 8   spotify:track:62ke5zFUJN6RvtXZgVH0F8
# 9   spotify:track:6BskTMfDjXVzeqQHOau5Vi
# 10  spotify:track:0o1OM5u467bWgysjNKIpY0
# 11  spotify:track:2XU0oxnq2qxCpomAAuJY8K
# 12  spotify:track:2wXJfz8R8p9igLjM5sBkkh
# 13  spotify:track:7IDoxdASgrwumbCuX8E58s
# 14  spotify:track:1dt220OBbkTsYz1NLVKIaw
# 15  spotify:track:5Sh2pJT3VWTvkQOXPAaRiC
# 16  spotify:track:7tCC6GEAhS5nIrd3ZahW0n
# 17  spotify:track:1rGZd7EVl4aOClpzDLNPwy
# 18  spotify:track:6L88EH68XwlaXwvChlTS41
# 19  spotify:track:2rXW2yxuRJoZhAZeowgomh
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/7AraSdlKIOoP...
# 1   https://api.spotify.com/v1/tracks/53zetdmdcvQn...
# 2   https://api.spotify.com/v1/tracks/5AGS8VxsLyHQ...
# 3   https://api.spotify.com/v1/tracks/6G4z9WbxyEeW...
# 4   https://api.spotify.com/v1/tracks/1BV0m40U0M4t...
# 5   https://api.spotify.com/v1/tracks/7rGjz05rxd9M...
# 6   https://api.spotify.com/v1/tracks/3E8qvYDyhKat...
# 7   https://api.spotify.com/v1/tracks/58GxgFEG5uHc...
# 8   https://api.spotify.com/v1/tracks/62ke5zFUJN6R...
# 9   https://api.spotify.com/v1/tracks/6BskTMfDjXVz...
# 10  https://api.spotify.com/v1/tracks/0o1OM5u467bW...
# 11  https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...
# 12  https://api.spotify.com/v1/tracks/2wXJfz8R8p9i...
# 13  https://api.spotify.com/v1/tracks/7IDoxdASgrwu...
# 14  https://api.spotify.com/v1/tracks/1dt220OBbkTs...
# 15  https://api.spotify.com/v1/tracks/5Sh2pJT3VWTv...
# 16  https://api.spotify.com/v1/tracks/7tCC6GEAhS5n...
# 17  https://api.spotify.com/v1/tracks/1rGZd7EVl4aO...
# 18  https://api.spotify.com/v1/tracks/6L88EH68Xwla...
# 19  https://api.spotify.com/v1/tracks/2rXW2yxuRJoZ...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/7Ara...      204760
# 1   https://api.spotify.com/v1/audio-analysis/53ze...      229686
# 2   https://api.spotify.com/v1/audio-analysis/5AGS...      226440
# 3   https://api.spotify.com/v1/audio-analysis/6G4z...      288915
# 4   https://api.spotify.com/v1/audio-analysis/1BV0...      280027
# 5   https://api.spotify.com/v1/audio-analysis/7rGj...      244893
# 6   https://api.spotify.com/v1/audio-analysis/3E8q...      192147
# 7   https://api.spotify.com/v1/audio-analysis/58Gx...      161001
# 8   https://api.spotify.com/v1/audio-analysis/62ke...      232893
# 9   https://api.spotify.com/v1/audio-analysis/6Bsk...      171803
# 10  https://api.spotify.com/v1/audio-analysis/0o1O...      347693
# 11  https://api.spotify.com/v1/audio-analysis/2XU0...      209438
# 12  https://api.spotify.com/v1/audio-analysis/2wXJ...      194000
# 13  https://api.spotify.com/v1/audio-analysis/7IDo...      229525
# 14  https://api.spotify.com/v1/audio-analysis/1dt2...      178310
# 15  https://api.spotify.com/v1/audio-analysis/5Sh2...      197504
# 16  https://api.spotify.com/v1/audio-analysis/7tCC...      206124
# 17  https://api.spotify.com/v1/audio-analysis/1rGZ...      204959
# 18  https://api.spotify.com/v1/audio-analysis/6L88...      240362
# 19  https://api.spotify.com/v1/audio-analysis/2rXW...      205320
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
#
# [20 rows x 22 columns]

# %%
result_df['MBTI'] = 'ENFP' # --> change as per MBTI type

# %%
# Save the extended DataFrame
result_df.to_csv('extended_songs_yoojin_dislike.csv', index=False) # --> change as per Name
