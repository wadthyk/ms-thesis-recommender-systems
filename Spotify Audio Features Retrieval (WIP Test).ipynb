# %% [markdown]
# ## Chapter 5) Methodology
# Code for analysis and ML workflow to build a recommender system and find music item similarities based on a user's listening history and liked/saved songs.
#
#
# ##### Steps (Brief Overview):
#
# **Data Collection & Processing (EDA Part)**
# 1. load all data available and store in Pandas data frames
# 2. connect to Spotify API using developer console to extract song features
# 3. create separate DFs for songs/playlists collected by friends and MBTI playlists downloaded from Kaggle
#
# **Feature Extraction & Selection**
# 4. clean the data and select feature columns for the model
#
# **Content Based Filtering on Base Dataset**
# 5. applying the different ML Models on Baseline Dataset Using Content Based Filtering and Evaluating Initial Results
#
# **Incorperating MBTI Perosnality Types in the Recommendation Process**
# 6. adding additional feature column for MBTI personality type and create MBTI based DFs from Kaggle Datasets
# 7. applying use-item Matrix factorization and evaluate results
#
# **Compare Results**
# 8. compare the results of baseline model with MBTI implemented model

# %% [markdown]
# #### Data Collection & Processing (EDA Part)

# %%
import pandas as pd
import seaborn as sns

# saving obtained playlists from friends and Kaggle datasets as Pandas DFs (your library = liked songs)

# %%
# example that worked for 1 DF

import json
import pandas as pd

# JSON file path of user
json_file_path_wadthy = '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json'

# Load the JSON file
with open(json_file_path_wadthy, 'r') as file:
    data = json.load(file)

# Extract song information
songs = data['tracks']

# Create a list to hold song data
song_list = []

# Iterate over each song and extract relevant details
for song in songs:
    song_info = {
        'Title': song.get('track', 'N/A'),
        'Artist': song.get('artist', 'N/A'),
        'Album': song.get('album', 'N/A'),
        'URI': song.get('uri', 'N/A')
    }
    song_list.append(song_info)

# Create a DataFrame from the song list
df = pd.DataFrame(song_list)

# Display the DataFrame
df.head(10)
# Out:
#                                 Title            Artist  \
# 0             Smells Like Teen Spirit           Nirvana
# 1                          Sure Thing            Miguel
# 2                         Fancy Shoes       The Walters
# 3                           Tokyo Inn            HYUKOH
# 4                        Konoha Peace              Kato
# 5    Wake Up Call - Mark Ronson Remix          Maroon 5
# 6     Stolen Dance - Acoustic Version      Milky Chance
# 7  Williamsburg - Urban Contact Remix      Purple Souls
# 8      DUELE EL CORAZON (feat. Wisin)  Enrique Iglesias
# 9                         Blank Space      Taylor Swift
#
#                             Album                                   URI
# 0                         Nirvana  spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1               All I Want Is You  spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2                  Songs for Dads  spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3                              23  spotify:track:4myeBw35GUMw5FyDGZcOON
# 4                    Naruto Vibes  spotify:track:0wIfYaveiZku0eL44UXtHk
# 5    It Won't Be Soon Before Long  spotify:track:4Q36omJXoeMD8LnnoOXOu7
# 6                    Sadnecessary  spotify:track:3DUhxfgyzNi0cCmZWDWfnS
# 7                    Williamsburg  spotify:track:3FRQ6ZBnsbiUEgr3fwyzHV
# 8  DUELE EL CORAZON (feat. Wisin)  spotify:track:6YZdkObH88npeKrrkb8Ggf
# 9                            1989  spotify:track:1u8c2t2Cy7UBoG4ArRcF5g

# %%
import json
import pandas as pd
import os

# List of JSON file paths
file_paths = [
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/01_YourLibrary_withy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/02_YourLibrary_yoojin.json'
]

# Dictionary to store DataFrames
dataframes = {}

# Loop through each file, load the data, and create a DataFrame
for file_path in file_paths:
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Extract song information
    songs = data['tracks']

    # Create a list to hold song data
    song_list = []

    # Iterate over each song and extract relevant details
    for song in songs:
        song_info = {
            'Title': song.get('track', 'N/A'),
            'Artist': song.get('artist', 'N/A'),
            'Album': song.get('album', 'N/A'),
            'URI': song.get('uri', 'N/A')
        }
        song_list.append(song_info)

    # Create a DataFrame from the song list
    df = pd.DataFrame(song_list)

    # Use the file name (without extension) as the key for the DataFrame in the dictionary
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    dataframes[file_name] = df

# Now dataframes dictionary holds DataFrames for each JSON file
for name, df in dataframes.items():
    print(f"DataFrame for {name}:")
    print(df)
# Out:
# DataFrame for 00_YourLibrary_wadthy:
#                         Title                 Artist                Album  \
# 0     Smells Like Teen Spirit                Nirvana              Nirvana
# 1                  Sure Thing                 Miguel    All I Want Is You
# 2                 Fancy Shoes            The Walters       Songs for Dads
# 3                   Tokyo Inn                 HYUKOH                   23
# 4                Konoha Peace                   Kato         Naruto Vibes
# ...                       ...                    ...                  ...
# 3152            Snow (Hey Oh)  Red Hot Chili Peppers     Stadium Arcadium
# 3153      Tell me you love me                Tophyun  Tell me you love me
# 3154                 Sunshine              Matisyahu         Spark Seeker
# 3155                     Sing             Ed Sheeran                    x
# 3156             Blue Spirits                 DWLLRS         Blue Spirits
#
#                                        URI
# 0     spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1     spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2     spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3     spotify:track:4myeBw35GUMw5FyDGZcOON
# 4     spotify:track:0wIfYaveiZku0eL44UXtHk
# ...                                    ...
# 3152  spotify:track:2aibwv5hGXSgw7Yru8IYTO
# 3153  spotify:track:0U5HgFCn3EJN2zZqI0KGfJ
# 3154  spotify:track:56ZDcszhe1eCeghso93fXP
# 3155  spotify:track:6K8qKeWo5MsFED7wCR6Kop
# 3156  spotify:track:4Z3Mmn6cIeuKprHQyyAbXQ
#
# [3157 rows x 4 columns]
# DataFrame for 01_YourLibrary_withy:
#                                          Title           Artist  \
# 0    Ordinaryish People (feat. Blue Man Group)              AJR
# 1                                     Good Day       Jake Scott
# 2                                   Oh My Love        The Score
# 3                                Conversations           Marney
# 4                                        Bones  Imagine Dragons
# ..                                         ...              ...
# 596                                        You    Keaton Henson
# 597                                      Karma              AJR
# 598                                     Animal       Noah Kahan
# 599                                      HAPPY               NF
# 600                                  Oh My God    Alec Benjamin
#
#                  Album                                   URI
# 0         OK ORCHESTRA  spotify:track:3sBdf3nxnEC9e2GcdP9d3j
# 1             Lavender  spotify:track:5zsTxXxpVzWC9MqeNJ3Pes
# 2                ATLAS  spotify:track:4Q99wmrzQFtK3oweyLkWij
# 3        Conversations  spotify:track:6XfjfDpIUWI0sE0WBBnQfD
# 4                Bones  spotify:track:0HqZX76SFLDz2aW8aiqi7G
# ..                 ...                                   ...
# 596          Birthdays  spotify:track:5R2YoUm4YFex1JaecdJs0h
# 597         Neotheater  spotify:track:3VygfAvvgVaJUeaBUSzlZu
# 598             Animal  spotify:track:6IP8DMuxscj75wxTErFXoh
# 599               HOPE  spotify:track:3ZEno9fORwMA1HPecdLi0R
# 600  These Two Windows  spotify:track:44I5NYJ7CGEcaLOuG2zJsU
#
# [601 rows x 4 columns]
# DataFrame for 02_YourLibrary_yoojin:
#                                                 Title                 Artist  \
# 0                               TOO BAD (prod. CarTa)            Anandelight
# 1               Young, Wild & Free (feat. Bruno Mars)             Snoop Dogg
# 2                            Dancing in the Moonlight              Toploader
# 3                                               NDGGA                 meenoi
# 4                                     Etude of Memory             Exhibition
# 5                                             Weekend                TAEYEON
# 6                                      Ah Koritsi Mou     Giannis Ploutarhos
# 7                                           Bumblebee                   ABBA
# 8                                      Den Thelo Allo     Giannis Ploutarhos
# 9                                  The Rubberband Man           The Spinners
# 10  Reset (Feat. Gaeko, Kid Milli) (Prod. CODE KUNST)                  SINCE
# 11                                         Take A Bow                Rihanna
# 12                                           Sir Duke  Quartet San Francisco
# 13                                          친구로 지내자면서          Hwang In Wook
# 14                                           DOWNPOUR                  I.O.I
# 15                Don't Stop Me Now - Remastered 2011                  Queen
# 16                                   LOST IN PARADISE                    ALI
# 17                                           Ta reine                 Angèle
# 18                  Kamia Den Miazi Me Sena Matia Mou     Giannis Ploutarhos
# 19                                         Lasse redn              Die Ärzte
# 20                                       Ipirhan Orki     Giannis Ploutarhos
# 21                                        Water Glass                 Cannon
# 22                                            FRIENDS                 lIlBOI
# 23                                         Der Zocker               Kollegah
# 24                                              11:11                TAEYEON
# 25  MERRY-GO-ROUND (Feat. Zion.T, Wonstein) (Prod....               sokodomo
# 26                                  LAst dAy oN EaRTh             Tai Verdes
# 27                             Angeberprollrap Deluxe               Kollegah
# 28                                         The Nights                 Avicii
# 29                                       Kaikai Kitan                    Eve
# 30                                         Heat Waves          Glass Animals
# 31                                         TWINTAIL20                 D-Hack
# 32                                       Eenie Meenie          Sean Kingston
# 33                                            Sailing            Rod Stewart
# 34                                  Wahdeh Bteshbahek                  Jadal
# 35                                Put Your Records On            Ritt Momney
# 36                                           PASS OUT           Nitti Gritti
# 37                                             No Cap        Blake and Miles
# 38                                     So gut wie neu             Alligatoah
# 39                08Basick (Feat. Yumdda, punchnello)                 Basick
# 40                      +82 (Prod. Dynamicduo, THAMA)               Paloalto
# 41                                          Two of Us        Louis Tomlinson
# 42                                               Gift               Genetikk
# 43                                  Love Me Like That                Sam Kim
# 44                                  Goldfish Crackers            Gold Revere
# 45                                     Bad Contestant           Matt Maltese
#
#                                                 Album  \
# 0                                             TOO BAD
# 1               Young, Wild & Free (feat. Bruno Mars)
# 2                                     Onka's Big Moka
# 3                                               NDGGA
# 4                                          Exhibition
# 5                                INVU - The 3rd Album
# 6                                  Mikres Fotografies
# 7                                              Voyage
# 8                                  I Dinami Tou Erota
# 9        The Rubberband Man / Now That We're Together
# 10                     Show Me The Money 10 Episode 3
# 11                       Good Girl Gone Bad: Reloaded
# 12                              Quartet San Francisco
# 13                                          친구로 지내자면서
# 14                                           DOWNPOUR
# 15                                               Jazz
# 16                                   LOST IN PARADISE
# 17                                               Brol
# 18                Den Ine O Erotas...Pedi Tis Logikis
# 19                                    Jazz ist anders
# 20                                       Ipirhan Orki
# 21                                        Water Glass
# 22                                            FRIENDS
# 23                               Zuhältertape, Vol. 5
# 24                           My Voice - The 1st Album
# 25                     Show Me The Money 10 Episode 2
# 26                                  LAst dAy oN EaRTh
# 27                               Zuhältertape, Vol. 5
# 28                                  The Days / Nights
# 29                         Kaikai Kitan / Ao No Waltz
# 30                                         Heat Waves
# 31                                         TWINTAIL20
# 32                                       Eenie Meenie
# 33                                  Atlantic Crossing
# 34                                            Malyoun
# 35                                Put Your Records On
# 36                                           PASS OUT
# 37                                             No Cap
# 38                         Schlaftabletten, Rotwein V
# 39                    Show Me The Money 10 Semi Final
# 40                         Show Me The Money 10 Final
# 41                                              Walls
# 42                                             D.N.A.
# 43  Nevertheless, (Original Television Soundtrack,...
# 44                                  Goldfish Crackers
# 45                                     Bad Contestant
#
#                                      URI
# 0   spotify:track:06vHdq1RN59tke4Ixq6usN
# 1   spotify:track:5HQVUIKwCEXpe7JIHyY734
# 2   spotify:track:3Fzlg5r1IjhLk2qRw667od
# 3   spotify:track:4k4PQkx007qoo6XPbijp9z
# 4   spotify:track:3YpiZu52TdVbNKExZpZAWW
# 5   spotify:track:0n1jo6k1GUzyrcXW2aS0iL
# 6   spotify:track:6RM4uRehk0XvKUzYO3Y93L
# 7   spotify:track:4dmSIn2DxtfX1rySnUDamj
# 8   spotify:track:3Su4Xx8b8ko1kGrjYs2CIh
# 9   spotify:track:13Mzsb8VzRSZ5w3pM48cn6
# 10  spotify:track:5oD7cKg3DRl2HFuybvVsI5
# 11  spotify:track:3goSVuTt3fDYDP6kRnFwuL
# 12  spotify:track:16ArKmfYyDsWqGowWt6ntf
# 13  spotify:track:4hRkuqTfL00G1MWmcyAk1j
# 14  spotify:track:3pMnRGNIgK0Ql19zvnjv83
# 15  spotify:track:5T8EDUDqKcs6OSOwEsfqG7
# 16  spotify:track:145wBbokDZTFZLFHOtZrzG
# 17  spotify:track:3iXhLi33EpUfcOwasC8un1
# 18  spotify:track:5ooI7eKotorrBsnJHcw5uS
# 19  spotify:track:5pPPd1mWUBZLejws9xf5Sp
# 20  spotify:track:5rZAgfcv0vpOZ0eQR1jdvF
# 21  spotify:track:4P5d7lMNGqMPcVBn994Lbp
# 22  spotify:track:1Y8tCOCqwav6RBvfNjYphx
# 23  spotify:track:7BmyLMNWvCT9odCB1rf0Bm
# 24  spotify:track:67QGnT1Vdfuuy4HkLTUVjj
# 25  spotify:track:2eLe81VDUQ5f0xFfc9cMWz
# 26  spotify:track:0fVDu1evgjX9CFD0cmuRrM
# 27  spotify:track:74HyR1BsvRJ67uar64DWNW
# 28  spotify:track:0ct6r3EGTcMLPtrXHDvVjc
# 29  spotify:track:6y4GYuZszeXNOXuBFsJlos
# 30  spotify:track:6CDzDgIUqeDY5g8ujExx2f
# 31  spotify:track:20hbf8BuH3xZcZZiL8eu32
# 32  spotify:track:4vVTI94F9uJ8lHNDWKv0i2
# 33  spotify:track:6OuRbvP4PgbuzBIapVzmFJ
# 34  spotify:track:5FDPmf9Dp0AaSYjeHW10ed
# 35  spotify:track:1fah1uAs7HeTYDlNftKr3K
# 36  spotify:track:0rLY9GG3le099LxnJ6Qgqy
# 37  spotify:track:2KclJjnLjul7NhyJrAhpUu
# 38  spotify:track:3F23UghPZhrix9SXebUuWY
# 39  spotify:track:0o420trQgUtPnbMgCEAEKi
# 40  spotify:track:2fDv60k440Zif7SzI6jXUw
# 41  spotify:track:1eqwjXdMTed8Pz3PLNcHe9
# 42  spotify:track:5j2M8xlHR2eU4YQK2XmzPa
# 43  spotify:track:1lhm29o3syw122xynSKaAK
# 44  spotify:track:0CSdTznqFECgu1DSciQC4v
# 45  spotify:track:2rVLAc6Zh70Vt75b9CgoBO

# %%
import json
import pandas as pd
import os

# List of JSON file paths --> local file path
file_paths = [
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/01_YourLibrary_withy.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/02_YourLibrary_yoojin.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/03_YourLibrary_moni.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/04_YourLibrary_nga.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/05_YourLibrary_makra.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/06_YourLibrary_sören.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/07_YourLibrary_simon.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/09_YourLibrary_yeonju.json',
    '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/10_YourLibrary_han.json'
]

# Dictionary to store DataFrames
dataframes = {}

# Loop through each file, load the data, and create a DataFrame
for file_path in file_paths:
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Extract song information
    songs = data['tracks']

    # Create a list to hold song data
    song_list = []

    # Iterate over each song and extract relevant details
    for song in songs:
        song_info = {
            'Title': song.get('track', 'N/A'),
            'Artist': song.get('artist', 'N/A'),
            'Album': song.get('album', 'N/A'),
            'URI': song.get('uri', 'N/A')
        }
        song_list.append(song_info)

    # Create a DataFrame from the song list
    df = pd.DataFrame(song_list)

    # Use the file name (without extension) as the key for the DataFrame in the dictionary
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    dataframes[file_name] = df

# Accessing and analyzing individual DataFrames
for name, df in dataframes.items():
    print(f"DataFrame for {name}:")
    print(df.head())  # Display the first few rows of the DataFrame

    # Example analysis: Print the number of songs in each DataFrame
    print(f"Number of songs in {name}: {len(df)}")

    # Optionally, save each DataFrame to a separate CSV file
    df.to_csv(f'{name}_songs.csv', index=False)

# Example of specific DataFrame access for further analysis


# Access a specific DataFrame by its key, e.g., "05_YourLibrary_makra" --> getting DFs of all collected Users
df_wadthy = dataframes.get("00_YourLibrary_wadthy")
df_withy = dataframes.get("01_YourLibrary_withy")
df_yoojin = dataframes.get("02_YourLibrary_yoojin")
df_moni = dataframes.get("03_YourLibrary_moni")
df_nga = dataframes.get("04_YourLibrary_nga")
df_makra = dataframes.get("05_YourLibrary_makra")
df_sören = dataframes.get("06_YourLibrary_sören")
df_simon = dataframes.get("07_YourLibrary_simon")
# van's daten
df_sören = dataframes.get("09_YourLibrary_sören")
df_han = dataframes.get("10_YourLibrary_han")
# trang's daten


if df_specific is not None:
    # Perform analysis on the specific DataFrame
    print(df_specific.describe())
else:
    print("The specified DataFrame does not exist.")
# Out:
# DataFrame for 00_YourLibrary_wadthy:
#                      Title       Artist              Album  \
# 0  Smells Like Teen Spirit      Nirvana            Nirvana
# 1               Sure Thing       Miguel  All I Want Is You
# 2              Fancy Shoes  The Walters     Songs for Dads
# 3                Tokyo Inn       HYUKOH                 23
# 4             Konoha Peace         Kato       Naruto Vibes
#
#                                     URI
# 0  spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1  spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2  spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3  spotify:track:4myeBw35GUMw5FyDGZcOON
# 4  spotify:track:0wIfYaveiZku0eL44UXtHk
# Number of songs in 00_YourLibrary_wadthy: 3157
# DataFrame for 01_YourLibrary_withy:
#                                        Title           Artist          Album  \
# 0  Ordinaryish People (feat. Blue Man Group)              AJR   OK ORCHESTRA
# 1                                   Good Day       Jake Scott       Lavender
# 2                                 Oh My Love        The Score          ATLAS
# 3                              Conversations           Marney  Conversations
# 4                                      Bones  Imagine Dragons          Bones
#
#                                     URI
# 0  spotify:track:3sBdf3nxnEC9e2GcdP9d3j
# 1  spotify:track:5zsTxXxpVzWC9MqeNJ3Pes
# 2  spotify:track:4Q99wmrzQFtK3oweyLkWij
# 3  spotify:track:6XfjfDpIUWI0sE0WBBnQfD
# 4  spotify:track:0HqZX76SFLDz2aW8aiqi7G
# Number of songs in 01_YourLibrary_withy: 601
# DataFrame for 02_YourLibrary_yoojin:
#                                    Title       Artist  \
# 0                  TOO BAD (prod. CarTa)  Anandelight
# 1  Young, Wild & Free (feat. Bruno Mars)   Snoop Dogg
# 2               Dancing in the Moonlight    Toploader
# 3                                  NDGGA       meenoi
# 4                        Etude of Memory   Exhibition
#
#                                    Album                                   URI
# 0                                TOO BAD  spotify:track:06vHdq1RN59tke4Ixq6usN
# 1  Young, Wild & Free (feat. Bruno Mars)  spotify:track:5HQVUIKwCEXpe7JIHyY734
# 2                        Onka's Big Moka  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 3                                  NDGGA  spotify:track:4k4PQkx007qoo6XPbijp9z
# 4                             Exhibition  spotify:track:3YpiZu52TdVbNKExZpZAWW
# Number of songs in 02_YourLibrary_yoojin: 46
#                   Title                   Artist      Album  \
# count              3157                     3157       3157
# unique             2801                     1489       2314
# top     I Can't Help It  Macklemore & Ryan Lewis  The Heist
# freq                  4                       43         33
#
#                                          URI
# count                                   3157
# unique                                  3157
# top     spotify:track:4hy4fb5D1KL50b3sng9cjw
# freq                                       1

# %%
# Access a specific DataFrame by its key, e.g., "05_YourLibrary_makra"
df_wadthy = dataframes.get("00_YourLibrary_wadthy")
df_wadthy.head(20)
# Out:
#                                           Title            Artist  \
# 0                       Smells Like Teen Spirit           Nirvana
# 1                                    Sure Thing            Miguel
# 2                                   Fancy Shoes       The Walters
# 3                                     Tokyo Inn            HYUKOH
# 4                                  Konoha Peace              Kato
# 5              Wake Up Call - Mark Ronson Remix          Maroon 5
# 6               Stolen Dance - Acoustic Version      Milky Chance
# 7            Williamsburg - Urban Contact Remix      Purple Souls
# 8                DUELE EL CORAZON (feat. Wisin)  Enrique Iglesias
# 9                                   Blank Space      Taylor Swift
# 10                                     No Games            Serani
# 11                                         Roar        Katy Perry
# 12             Broken Stereo (Acoustic Version)     Sean Fournier
# 13                                Boom Boom Pow   Black Eyed Peas
# 14      We Are Never Ever Getting Back Together      Taylor Swift
# 15                                    Serotonin             Nic D
# 16                                     Criminal              Dayo
# 17                                        Mercy             Duffy
# 18  Quiet the Sun (Rough Version) - Bonus Track      Jeremy Loops
# 19                                 Me After You          Paul Kim
#
#                                  Album                                   URI
# 0                              Nirvana  spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1                    All I Want Is You  spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2                       Songs for Dads  spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3                                   23  spotify:track:4myeBw35GUMw5FyDGZcOON
# 4                         Naruto Vibes  spotify:track:0wIfYaveiZku0eL44UXtHk
# 5         It Won't Be Soon Before Long  spotify:track:4Q36omJXoeMD8LnnoOXOu7
# 6                         Sadnecessary  spotify:track:3DUhxfgyzNi0cCmZWDWfnS
# 7                         Williamsburg  spotify:track:3FRQ6ZBnsbiUEgr3fwyzHV
# 8       DUELE EL CORAZON (feat. Wisin)  spotify:track:6YZdkObH88npeKrrkb8Ggf
# 9                                 1989  spotify:track:1u8c2t2Cy7UBoG4ArRcF5g
# 10                            No Games  spotify:track:3WU2blK7YBcugEEU9CATvF
# 11                               PRISM  spotify:track:27tNWlhdAryQY04Gb2ZhUI
# 12                               Oh My  spotify:track:1zPfk2vaGcqXMn22PD9DuT
# 13  THE E.N.D. (THE ENERGY NEVER DIES)  spotify:track:3oDFtOhcN08qeDPAK6MEQG
# 14                                 Red  spotify:track:6kISMRfweKSvgHR0urMQFG
# 15                           Serotonin  spotify:track:1FUQZYqWRVL8eaQd7uENlz
# 16                            Criminal  spotify:track:0aExDA451hXHJey8r08nBN
# 17                           Rockferry  spotify:track:1zusIxNqJu8i4g6P6hJ2Qa
# 18                      Trading Change  spotify:track:1YoJUoCMVeWsfMzDg0hT1A
# 19                        Me After You  spotify:track:5AkyvofVWUqds8x1HHgDU9

# %%
df_withy = dataframes.get("01_YourLibrary_withy")
df_withy.head(20)
# Out:
#                                         Title                Artist  \
# 0   Ordinaryish People (feat. Blue Man Group)                   AJR
# 1                                    Good Day            Jake Scott
# 2                                  Oh My Love             The Score
# 3                               Conversations                Marney
# 4                                       Bones       Imagine Dragons
# 5                                 Uma Thurman          Fall Out Boy
# 6                                      Ghosts               BANNERS
# 7               all the good girls go to hell         Billie Eilish
# 8                                     Control          Broken Bells
# 9                            I Like Me Better                  Lauv
# 10            Gallows (feat. Jamie N Commons)             The Score
# 11                        Hide (feat. Seezyn)            Juice WRLD
# 12                        Fallin (Temptation)              grandson
# 13                                    Houndin                 Layto
# 14                                   Adderall             Max Frost
# 15                                      Bang!                   AJR
# 16                                    My Type           Saint Motel
# 17                               100 Bad Days                   AJR
# 18                   They Don't Care About Us  Matty Carter + Ariel
# 19                           Woke The F*ck Up           Jon Bellion
#
#                                        Album  \
# 0                               OK ORCHESTRA
# 1                                   Lavender
# 2                                      ATLAS
# 3                              Conversations
# 4                                      Bones
# 5            American Beauty/American Psycho
# 6                                     Ghosts
# 7   WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 8                            After the Disco
# 9                   I met you when I was 18.
# 10                                  Carry On
# 11         Spider-Man: Into the Spider-Verse
# 12                   a modern tragedy vol. 2
# 13                                   Houndin
# 14                                  Adderall
# 15                              OK ORCHESTRA
# 16                                   My Type
# 17                                Neotheater
# 18                  They Don't Care About Us
# 19                       The Human Condition
#
#                                      URI
# 0   spotify:track:3sBdf3nxnEC9e2GcdP9d3j
# 1   spotify:track:5zsTxXxpVzWC9MqeNJ3Pes
# 2   spotify:track:4Q99wmrzQFtK3oweyLkWij
# 3   spotify:track:6XfjfDpIUWI0sE0WBBnQfD
# 4   spotify:track:0HqZX76SFLDz2aW8aiqi7G
# 5   spotify:track:5PUawWFG1oIS2NwEcyHaCr
# 6   spotify:track:2YGqpzBhtJxt9M5g1czYg4
# 7   spotify:track:6IRdLKIyS4p7XNiP8r6rsx
# 8   spotify:track:1QZJiYulh7ak7GpZ8OAdwI
# 9   spotify:track:0EcQcdcbQeVJn9fknj44Be
# 10  spotify:track:20jNAwfYmyUCLqNXZZpzrj
# 11  spotify:track:6rz0dTA0PdhXImFV5EjM0w
# 12  spotify:track:1pyljdnXoCMK6KBchy8WCk
# 13  spotify:track:25R4HkFnzQvgMA6XOJuh4K
# 14  spotify:track:4Xx0J00u90QvnG3rwz4Itp
# 15  spotify:track:2I2AqFb0f9UNnolWc2MafC
# 16  spotify:track:2DFi8rwHcVkTTgu7PULhtI
# 17  spotify:track:0WmH9fXWCQ51RQi1kWPJrI
# 18  spotify:track:1Bs4W0jOXzBVm56NQdk3J4
# 19  spotify:track:5jKMjgG0J08rCezDvAX0sn

# %%
import json
import pandas as pd

# JSON file path of user
json_file_path_wadthy = '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json'

# Load the JSON file
with open(json_file_path_wadthy, 'r') as file:
    data = json.load(file)

# Inspect the structure of the JSON
print(json.dumps(data, indent=2))

# Extract song information (Assuming the JSON structure contains a key 'tracks' with song details)
songs = data['tracks']

# Create a list to hold song data
song_list = []

# Iterate over each song and extract relevant details
for song in songs:
    song_info = {
        'Title': song['track']['track_name'],
        'Artist': song['track']['artist_name'],
        'Album': song['track']['album_name'],
        'Added Date': song['added_at']
    }
    song_list.append(song_info)

# Create a DataFrame from the song list
df = pd.DataFrame(song_list)

# Display the DataFrame
print(df)

# %%
df.head(20)
# Out:
#    name artist album added_at                                   uri
# 0                              spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1                              spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2                              spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3                              spotify:track:4myeBw35GUMw5FyDGZcOON
# 4                              spotify:track:0wIfYaveiZku0eL44UXtHk
# 5                              spotify:track:4Q36omJXoeMD8LnnoOXOu7
# 6                              spotify:track:3DUhxfgyzNi0cCmZWDWfnS
# 7                              spotify:track:3FRQ6ZBnsbiUEgr3fwyzHV
# 8                              spotify:track:6YZdkObH88npeKrrkb8Ggf
# 9                              spotify:track:1u8c2t2Cy7UBoG4ArRcF5g
# 10                             spotify:track:3WU2blK7YBcugEEU9CATvF
# 11                             spotify:track:27tNWlhdAryQY04Gb2ZhUI
# 12                             spotify:track:1zPfk2vaGcqXMn22PD9DuT
# 13                             spotify:track:3oDFtOhcN08qeDPAK6MEQG
# 14                             spotify:track:6kISMRfweKSvgHR0urMQFG
# 15                             spotify:track:1FUQZYqWRVL8eaQd7uENlz
# 16                             spotify:track:0aExDA451hXHJey8r08nBN
# 17                             spotify:track:1zusIxNqJu8i4g6P6hJ2Qa
# 18                             spotify:track:1YoJUoCMVeWsfMzDg0hT1A
# 19                             spotify:track:5AkyvofVWUqds8x1HHgDU9

# %%
import pandas as pd
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# JSON file path of user
json_file_path_wadthy = '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Collected Spotify Data from Friends/All Extracted Library/00_YourLibrary_wadthy.json'

# load the JSON file
with open(json_file_path_wadthy, 'r', encoding='utf-8') as file:
    data = json.load(file)


# Check if 'tracks' is a list or a string
if isinstance(data, str):
    # If data is a string, try to parse it as JSON
    data = json.loads(data)

# Ensure 'tracks' is a list
tracks = data if isinstance(data, list) else data.get('tracks', [])

# Create a list to store the extracted information
tracks_data = []

# Extract relevant information from each track
for track in tracks:
    if isinstance(track, dict):
        tracks_data.append({
            'name': track.get('trackName', ''),
            'artist': track.get('artistName', ''),
            'album': track.get('albumName', ''),
            'added_at': track.get('addedDate', ''),
            'uri': track.get('uri', '')
        })
    elif isinstance(track, str):
        # If track is a string, it might be a JSON string
        try:
            track_dict = json.loads(track)
            tracks_data.append({
                'name': track_dict.get('trackName', ''),
                'artist': track_dict.get('artistName', ''),
                'album': track_dict.get('albumName', ''),
                'added_at': track_dict.get('addedDate', ''),
                'uri': track_dict.get('uri', '')
            })
        except json.JSONDecodeError:
            print(f"Skipping invalid track data: {track}")

# Create a pandas DataFrame
df = pd.DataFrame(tracks_data)

# Display the first few rows of the DataFrame
print(df.head(20))
# Out:
#    name artist album added_at                                   uri
# 0                              spotify:track:4hy4fb5D1KL50b3sng9cjw
# 1                              spotify:track:0JXXNGljqupsJaZsgSbMZV
# 2                              spotify:track:1YVVAiBD5WhX2ZdHtlSOhz
# 3                              spotify:track:4myeBw35GUMw5FyDGZcOON
# 4                              spotify:track:0wIfYaveiZku0eL44UXtHk
# 5                              spotify:track:4Q36omJXoeMD8LnnoOXOu7
# 6                              spotify:track:3DUhxfgyzNi0cCmZWDWfnS
# 7                              spotify:track:3FRQ6ZBnsbiUEgr3fwyzHV
# 8                              spotify:track:6YZdkObH88npeKrrkb8Ggf
# 9                              spotify:track:1u8c2t2Cy7UBoG4ArRcF5g
# 10                             spotify:track:3WU2blK7YBcugEEU9CATvF
# 11                             spotify:track:27tNWlhdAryQY04Gb2ZhUI
# 12                             spotify:track:1zPfk2vaGcqXMn22PD9DuT
# 13                             spotify:track:3oDFtOhcN08qeDPAK6MEQG
# 14                             spotify:track:6kISMRfweKSvgHR0urMQFG
# 15                             spotify:track:1FUQZYqWRVL8eaQd7uENlz
# 16                             spotify:track:0aExDA451hXHJey8r08nBN
# 17                             spotify:track:1zusIxNqJu8i4g6P6hJ2Qa
# 18                             spotify:track:1YoJUoCMVeWsfMzDg0hT1A
# 19                             spotify:track:5AkyvofVWUqds8x1HHgDU9

# %%
print(json.dumps(data[:2], indent=2))  # Print the first two items of the data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(json.dumps(data[:2], indent=2))  # Print the first two items of the data
#
# TypeError: unhashable type: 'slice'

# %%
# Save the DataFrame to a CSV file (optional)
df.to_csv('liked_songs.csv', index=False)

# %%
# You would normalize the songs in each playlist like this:
playlists = pd.json_normalize(data, record_path=['playlists', 'items'],
                              meta=[['playlists', 'items']])

# Step 3: Create a DataFrame
# If 'data' is already in a format that can be directly converted to a DataFrame, you could skip step 2
df = pd.DataFrame(playlists)

# Rename columns if necessary
df.rename(columns={'playlists.name': 'Playlist Name'}, inplace=True)

# Display the DataFrame
print(df)



# Extract liked songs from the 'tracks' key
liked_songs = data.get('tracks', [])

# Create a list to store the extracted information
tracks_data = []

# Extract relevant information from each track
for track in liked_songs:
    tracks_data.append({
        'name': track.get('track', {}).get('trackName', ''),
        'artist': track.get('track', {}).get('artistName', ''),
        'album': track.get('track', {}).get('albumName', ''),
        'added_at': track.get('addedDate', ''),
        'uri': track.get('uri', '')
    })

# Display the first few rows of the DataFrame
print(df.head())

# %%
# Spotify credentials
client_id = '582341de1c87493291783ae774754039'
client_secret = 'a21c97ce2062459a8f257d476ed5fe97'

# Authenticate with Spotify
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# List of track IDs (replace these with the actual Spotify track IDs you're interested in)
track_ids = ['1KU5EHSz04JhGg3rReGJ0N']

# Initialize empty list to hold track details and audio features
tracks_data = []

# Retrieve track details and audio features for each track
for track_id in track_ids:
    track_details = sp.track(track_id)
    audio_features = sp.audio_features(track_id)[0]

    track_info = {
        'title': track_details['name'],
        'artist_name': track_details['artists'][0]['name'],
        'release_date': track_details['album']['release_date'],
        'genre': '',  # Spotify API does not provide genre at the track level, usually available at the artist level
        'duration_ms': track_details['duration_ms'],
        'danceability': audio_features['danceability'],
        'energy': audio_features['energy'],
        'key': audio_features['key'],
        'loudness': audio_features['loudness'],
        'mode': audio_features['mode'],
        'speechiness': audio_features['speechiness'],
        'acousticness': audio_features['acousticness'],
        'instrumentalness': audio_features['instrumentalness'],
        'liveness': audio_features['liveness'],
        'valence': audio_features['valence'],
        'tempo': audio_features['tempo'],
    }

    tracks_data.append(track_info)

# Convert list of dicts to pandas DataFrame
df_tracks = pd.DataFrame(tracks_data)

# Display the DataFrame
print(df_tracks)

# %%
df_tracks.head()
# Out:
#           title    artist_name release_date genre  duration_ms  danceability  \
# 0  Black Velvet  Alannah Myles   1989-03-14             287440         0.754
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.366    8    -10.07     1       0.0312         0.273           0.00009
#
#    liveness  valence   tempo
# 0     0.106    0.469  91.147

# %% [markdown]
# ### Retrieving the Data from Spotify as JSON and Normalize to Pandas Data Frame

# %%
import json

# %%
# Path to your JSON file
json_file_path = '/Users/khieuvon/Documents/10_Personal Stuff/01_Masterarbeit/Data for ML Model/Spotify Data/Spotify-Data_Sören/Playlist1.json'

# Step 1: Read the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Assuming 'data' contains a list of playlists, and each playlist has a list of songs
# You might need to adjust the path to 'records' based on the structure of your JSON

# Step 2: Normalize the data (if necessary)
# For example, if your data structure is:
# {
#    "playlists": [
#        {
#            "name": "Playlist 1",
#            "lastModifiedDate": "2022-09-17",
#            "items": [
#                {"track": "Song 1", "artist": "Artist 1"},
#                ...
#            ]
#        },
#                {
#    "track": {
#        "trackName": "Gold",
#        "artistName": "Chet Faker",
#        "albumName": "Built on Glass",
#        "trackUri": "spotify:track:1Ll09EiN5ffeFl1xNZB2Uk"
#    },
#    "episode": null,
#    "localTrack": null,
#    "addedDate": "2022-08-22"
#  },
#    ]
# }
# You would normalize the songs in each playlist like this:
playlists = pd.json_normalize(data, record_path=['playlists', 'items'],
                              meta=[['playlists', 'items']])

# Step 3: Create a DataFrame
# If 'data' is already in a format that can be directly converted to a DataFrame, you could skip step 2
df = pd.DataFrame(playlists)

# Rename columns if necessary
df.rename(columns={'playlists.name': 'Playlist Name'}, inplace=True)

# Display the DataFrame
print(df)
# Out:
#      episode localTrack   addedDate             track.trackName  \
# 0       None       None  2022-08-22                        Gold
# 1       None       None  2022-08-22                   Sunflower
# 2       None       None  2022-08-22      Trampoline (with ZAYN)
# 3       None       None  2022-08-22                         You
# 4       None       None  2022-08-22                 Imagination
# ...      ...        ...         ...                         ...
# 1200    None       None  2022-10-06                        Lies
# 1201    None       None  2022-10-18   CHANT (feat. Tones And I)
# 1202    None       None  2022-10-18              3 Tage am Meer
# 1203    None       None  2022-10-20                   telepatía
# 1204    None       None  2022-10-20  Mind Over Matter (Reprise)
#
#        track.artistName                          track.albumName  \
# 0            Chet Faker                           Built on Glass
# 1     Rex Orange County                                Sunflower
# 2                 SHAED                            Melt (Deluxe)
# 3                Regard                                      You
# 4           Gorgon City                                   Sirens
# ...                 ...                                      ...
# 1200        Say Yes Dog                                   Voyage
# 1201         Macklemore                CHANT (feat. Tones And I)
# 1202  AnnenMayKantereit                           3 Tage am Meer
# 1203         Kali Uchis  Sin Miedo (del Amor y Otros Demonios) ∞
# 1204    Young the Giant  Mirrorball / Mind Over Matter (Reprise)
#
#                             track.trackUri  \
# 0     spotify:track:1Ll09EiN5ffeFl1xNZB2Uk
# 1     spotify:track:4EpZ4eYuZOwPSSwyqpdHnJ
# 2     spotify:track:2ez6qvOTHKeI3ss80NGqnI
# 3     spotify:track:2cc8Sw1OnCuA5bV8nqWqpE
# 4     spotify:track:3ZrWmt3DGH75hItHp6uWLz
# ...                                    ...
# 1200  spotify:track:0Zzur28YBbI93bgjo0YdNR
# 1201  spotify:track:5BgeAX4HuZdcuCqmu4pIMM
# 1202  spotify:track:7vmxzqidBt7y4FxRtsJBVV
# 1203  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
# 1204  spotify:track:77KnJc8o5G1eKVwX5ywMeZ
#
#                                         playlists.items
# 0     [{'track': {'trackName': 'Gold', 'artistName':...
# 1     [{'track': {'trackName': 'Gold', 'artistName':...
# 2     [{'track': {'trackName': 'Gold', 'artistName':...
# 3     [{'track': {'trackName': 'Gold', 'artistName':...
# 4     [{'track': {'trackName': 'Gold', 'artistName':...
# ...                                                 ...
# 1200  [{'track': {'trackName': 'golden hour', 'artis...
# 1201  [{'track': {'trackName': 'golden hour', 'artis...
# 1202  [{'track': {'trackName': 'golden hour', 'artis...
# 1203  [{'track': {'trackName': 'golden hour', 'artis...
# 1204  [{'track': {'trackName': 'golden hour', 'artis...
#
# [1205 rows x 8 columns]

# %%
df.head(20)
# Out:
#    episode localTrack   addedDate                      track.trackName  \
# 0     None       None  2022-08-22                                 Gold
# 1     None       None  2022-08-22                            Sunflower
# 2     None       None  2022-08-22               Trampoline (with ZAYN)
# 3     None       None  2022-08-22                                  You
# 4     None       None  2022-08-22                          Imagination
# 5     None       None  2022-08-22                         I'm Into You
# 6     None       None  2022-08-27                         Black Velvet
# 7     None       None  2022-09-12                           Powerslide
# 8     None       None  2022-09-17                            Fade Away
# 9     None       None  2022-07-24      Shout (Tears for Fears) - Remix
# 10    None       None  2022-07-24          Crazy In Love (feat. Jay-Z)
# 11    None       None  2022-07-24                            I Like It
# 12    None       None  2022-07-24       Finesse - Remix; feat. Cardi B
# 13    None       None  2022-07-24                    Shut Up And Drive
# 14    None       None  2022-07-25                            sweetener
# 15    None       None  2022-07-25                 no tears left to cry
# 16    None       None  2022-07-25                                  SOS
# 17    None       None  2022-07-25                                 1999
# 18    None       None  2022-07-25           My My My! - Throttle Remix
# 19    None       None  2022-07-25  Dance To This (feat. Ariana Grande)
#
#      track.artistName                  track.albumName  \
# 0          Chet Faker                   Built on Glass
# 1   Rex Orange County                        Sunflower
# 2               SHAED                    Melt (Deluxe)
# 3              Regard                              You
# 4         Gorgon City                           Sirens
# 5          Chet Faker             Thinking In Textures
# 6       Alannah Myles                    Alannah Myles
# 7         Ryan Beatty                     Boy in Jeans
# 8     Susanne Sundfør                   Ten Love Songs
# 9         Alex Graham          Shout (Tears for Fears)
# 10            Beyoncé              Dangerously In Love
# 11            Cardi B              Invasion of Privacy
# 12         Bruno Mars  Finesse (Remix) [feat. Cardi B]
# 13            Rihanna     Good Girl Gone Bad: Reloaded
# 14      Ariana Grande                        Sweetener
# 15      Ariana Grande                        Sweetener
# 16            Rihanna                   A Girl Like Me
# 17         Charli XCX                           Charli
# 18        Troye Sivan                        My My My!
# 19        Troye Sivan                            Bloom
#
#                           track.trackUri  \
# 0   spotify:track:1Ll09EiN5ffeFl1xNZB2Uk
# 1   spotify:track:4EpZ4eYuZOwPSSwyqpdHnJ
# 2   spotify:track:2ez6qvOTHKeI3ss80NGqnI
# 3   spotify:track:2cc8Sw1OnCuA5bV8nqWqpE
# 4   spotify:track:3ZrWmt3DGH75hItHp6uWLz
# 5   spotify:track:2mbu1ssfb7h1RNO5jBv4cW
# 6   spotify:track:1KU5EHSz04JhGg3rReGJ0N
# 7   spotify:track:5x1Ctt9JCZNU5UhJWbHoQp
# 8   spotify:track:0IWBaEf7GOwKPKHyC32E1z
# 9   spotify:track:5FFiJ0zzCJmzz0HDrPCdh7
# 10  spotify:track:5IVuqXILoxVWvWEPm82Jxr
# 11  spotify:track:58q2HKrzhC3ozto2nDdN4z
# 12  spotify:track:3Vo4wInECJQuz9BIBMOu8i
# 13  spotify:track:3m7Fne4xA0bsKzEaWbNucr
# 14  spotify:track:70khXICDeTTxgYtw3EysKH
# 15  spotify:track:2qT1uLXPVPzGgFOx4jtEuo
# 16  spotify:track:30cSNer6TV8x2utjULVeQ5
# 17  spotify:track:3WGJSY8JaGliVIJyMig5aS
# 18  spotify:track:4iUmJaymwtbxhyMTrTnULU
# 19  spotify:track:2NjO87HyT80fsgejd3PLYW
#
#                                       playlists.items
# 0   [{'track': {'trackName': 'Gold', 'artistName':...
# 1   [{'track': {'trackName': 'Gold', 'artistName':...
# 2   [{'track': {'trackName': 'Gold', 'artistName':...
# 3   [{'track': {'trackName': 'Gold', 'artistName':...
# 4   [{'track': {'trackName': 'Gold', 'artistName':...
# 5   [{'track': {'trackName': 'Gold', 'artistName':...
# 6   [{'track': {'trackName': 'Gold', 'artistName':...
# 7   [{'track': {'trackName': 'Gold', 'artistName':...
# 8   [{'track': {'trackName': 'Gold', 'artistName':...
# 9   [{'track': {'trackName': 'Shout (Tears for Fea...
# 10  [{'track': {'trackName': 'Shout (Tears for Fea...
# 11  [{'track': {'trackName': 'Shout (Tears for Fea...
# 12  [{'track': {'trackName': 'Shout (Tears for Fea...
# 13  [{'track': {'trackName': 'Shout (Tears for Fea...
# 14  [{'track': {'trackName': 'Shout (Tears for Fea...
# 15  [{'track': {'trackName': 'Shout (Tears for Fea...
# 16  [{'track': {'trackName': 'Shout (Tears for Fea...
# 17  [{'track': {'trackName': 'Shout (Tears for Fea...
# 18  [{'track': {'trackName': 'Shout (Tears for Fea...
# 19  [{'track': {'trackName': 'Shout (Tears for Fea...

# %%
# step 2 is to extract the trackUri in the column for each song and get only the string ID
# df_adjusted_trackUri = df

df['trackUri_ID'] = df["track.trackUri"].str[14:]

# %%
df.head(20)
# Out:
#    episode localTrack   addedDate                      track.trackName  \
# 0     None       None  2022-08-22                                 Gold
# 1     None       None  2022-08-22                            Sunflower
# 2     None       None  2022-08-22               Trampoline (with ZAYN)
# 3     None       None  2022-08-22                                  You
# 4     None       None  2022-08-22                          Imagination
# 5     None       None  2022-08-22                         I'm Into You
# 6     None       None  2022-08-27                         Black Velvet
# 7     None       None  2022-09-12                           Powerslide
# 8     None       None  2022-09-17                            Fade Away
# 9     None       None  2022-07-24      Shout (Tears for Fears) - Remix
# 10    None       None  2022-07-24          Crazy In Love (feat. Jay-Z)
# 11    None       None  2022-07-24                            I Like It
# 12    None       None  2022-07-24       Finesse - Remix; feat. Cardi B
# 13    None       None  2022-07-24                    Shut Up And Drive
# 14    None       None  2022-07-25                            sweetener
# 15    None       None  2022-07-25                 no tears left to cry
# 16    None       None  2022-07-25                                  SOS
# 17    None       None  2022-07-25                                 1999
# 18    None       None  2022-07-25           My My My! - Throttle Remix
# 19    None       None  2022-07-25  Dance To This (feat. Ariana Grande)
#
#      track.artistName                  track.albumName  \
# 0          Chet Faker                   Built on Glass
# 1   Rex Orange County                        Sunflower
# 2               SHAED                    Melt (Deluxe)
# 3              Regard                              You
# 4         Gorgon City                           Sirens
# 5          Chet Faker             Thinking In Textures
# 6       Alannah Myles                    Alannah Myles
# 7         Ryan Beatty                     Boy in Jeans
# 8     Susanne Sundfør                   Ten Love Songs
# 9         Alex Graham          Shout (Tears for Fears)
# 10            Beyoncé              Dangerously In Love
# 11            Cardi B              Invasion of Privacy
# 12         Bruno Mars  Finesse (Remix) [feat. Cardi B]
# 13            Rihanna     Good Girl Gone Bad: Reloaded
# 14      Ariana Grande                        Sweetener
# 15      Ariana Grande                        Sweetener
# 16            Rihanna                   A Girl Like Me
# 17         Charli XCX                           Charli
# 18        Troye Sivan                        My My My!
# 19        Troye Sivan                            Bloom
#
#                           track.trackUri  \
# 0   spotify:track:1Ll09EiN5ffeFl1xNZB2Uk
# 1   spotify:track:4EpZ4eYuZOwPSSwyqpdHnJ
# 2   spotify:track:2ez6qvOTHKeI3ss80NGqnI
# 3   spotify:track:2cc8Sw1OnCuA5bV8nqWqpE
# 4   spotify:track:3ZrWmt3DGH75hItHp6uWLz
# 5   spotify:track:2mbu1ssfb7h1RNO5jBv4cW
# 6   spotify:track:1KU5EHSz04JhGg3rReGJ0N
# 7   spotify:track:5x1Ctt9JCZNU5UhJWbHoQp
# 8   spotify:track:0IWBaEf7GOwKPKHyC32E1z
# 9   spotify:track:5FFiJ0zzCJmzz0HDrPCdh7
# 10  spotify:track:5IVuqXILoxVWvWEPm82Jxr
# 11  spotify:track:58q2HKrzhC3ozto2nDdN4z
# 12  spotify:track:3Vo4wInECJQuz9BIBMOu8i
# 13  spotify:track:3m7Fne4xA0bsKzEaWbNucr
# 14  spotify:track:70khXICDeTTxgYtw3EysKH
# 15  spotify:track:2qT1uLXPVPzGgFOx4jtEuo
# 16  spotify:track:30cSNer6TV8x2utjULVeQ5
# 17  spotify:track:3WGJSY8JaGliVIJyMig5aS
# 18  spotify:track:4iUmJaymwtbxhyMTrTnULU
# 19  spotify:track:2NjO87HyT80fsgejd3PLYW
#
#                                       playlists.items             trackUri_ID
# 0   [{'track': {'trackName': 'Gold', 'artistName':...  1Ll09EiN5ffeFl1xNZB2Uk
# 1   [{'track': {'trackName': 'Gold', 'artistName':...  4EpZ4eYuZOwPSSwyqpdHnJ
# 2   [{'track': {'trackName': 'Gold', 'artistName':...  2ez6qvOTHKeI3ss80NGqnI
# 3   [{'track': {'trackName': 'Gold', 'artistName':...  2cc8Sw1OnCuA5bV8nqWqpE
# 4   [{'track': {'trackName': 'Gold', 'artistName':...  3ZrWmt3DGH75hItHp6uWLz
# 5   [{'track': {'trackName': 'Gold', 'artistName':...  2mbu1ssfb7h1RNO5jBv4cW
# 6   [{'track': {'trackName': 'Gold', 'artistName':...  1KU5EHSz04JhGg3rReGJ0N
# 7   [{'track': {'trackName': 'Gold', 'artistName':...  5x1Ctt9JCZNU5UhJWbHoQp
# 8   [{'track': {'trackName': 'Gold', 'artistName':...  0IWBaEf7GOwKPKHyC32E1z
# 9   [{'track': {'trackName': 'Shout (Tears for Fea...  5FFiJ0zzCJmzz0HDrPCdh7
# 10  [{'track': {'trackName': 'Shout (Tears for Fea...  5IVuqXILoxVWvWEPm82Jxr
# 11  [{'track': {'trackName': 'Shout (Tears for Fea...  58q2HKrzhC3ozto2nDdN4z
# 12  [{'track': {'trackName': 'Shout (Tears for Fea...  3Vo4wInECJQuz9BIBMOu8i
# 13  [{'track': {'trackName': 'Shout (Tears for Fea...  3m7Fne4xA0bsKzEaWbNucr
# 14  [{'track': {'trackName': 'Shout (Tears for Fea...  70khXICDeTTxgYtw3EysKH
# 15  [{'track': {'trackName': 'Shout (Tears for Fea...  2qT1uLXPVPzGgFOx4jtEuo
# 16  [{'track': {'trackName': 'Shout (Tears for Fea...  30cSNer6TV8x2utjULVeQ5
# 17  [{'track': {'trackName': 'Shout (Tears for Fea...  3WGJSY8JaGliVIJyMig5aS
# 18  [{'track': {'trackName': 'Shout (Tears for Fea...  4iUmJaymwtbxhyMTrTnULU
# 19  [{'track': {'trackName': 'Shout (Tears for Fea...  2NjO87HyT80fsgejd3PLYW
